# %%
import os
os.chdir("/home/am23mtech11006/AM23MTECH11006/Physics informed_laser")

import sys
sys.path.append('./src')
import numpy as np
import torch
torch.manual_seed(0)
import torch.nn as nn
from torch.autograd import Variable,grad
from src.model import FNN
from src.util import *
from src.train import *

# %%
def PDE(x,y,z,t,net):
    X = torch.cat([x,y,z,t],axis=-1)
    T = net(X)
    
    T_t = grad(T,t,create_graph=True,grad_outputs=torch.ones_like(T))[0]

    T_x = grad(T,x,create_graph=True,grad_outputs=torch.ones_like(T))[0]
    T_xx = grad(T_x,x,create_graph=True,grad_outputs=torch.ones_like(T_x))[0]
    
    T_y = grad(T,y,create_graph=True,grad_outputs=torch.ones_like(T))[0]
    T_yy = grad(T_y,y,create_graph=True,grad_outputs=torch.ones_like(T_y))[0]
    
    T_z = grad(T,z,create_graph=True,grad_outputs=torch.ones_like(T))[0]
    T_zz = grad(T_z,z,create_graph=True,grad_outputs=torch.ones_like(T_z))[0]
    
    f = rho*Cp*T_t - k*(T_xx+T_yy+T_zz)

    return f

# %%
def generate_points(p=[],f=[]):

    t = np.linspace(x_min[3]+0.01,x_max[3],61)

    # boundary points
    bound_x_neg,_ = sampling_uniform(1.,x_min,x_max,'-x',t)
    bound_x_pos,_ = sampling_uniform(1.,x_min,x_max,'+x',t)

    bound_y_neg,_ = sampling_uniform(1.,x_min,x_max,'-y',t)
    bound_y_pos,_ = sampling_uniform(1.,x_min,x_max,'+y',t)

    bound_z_neg,_ = sampling_uniform(1.,x_min,x_max,'-z',t)
    bound_z_pos,_ = sampling_uniform(1.,x_min,x_max,'+z',t)

    bound_z_pos_more = [] # more points for surface flux
    
    for ti in t:
        if ti<=t_end:
            zi,_ = sampling_uniform(.25,
                        [max(x0+ti*v-2*r,x_min[0]),max(x_min[1],y0-2*r),x_min[2]],
                        [min(x0+ti*v+2*r,x_max[0]),min(x_max[1],y0+2*r),x_max[2]],
                        '+z',[ti])
            bound_z_pos_more.append(zi)

    bound_z_pos_more = np.vstack(bound_z_pos_more)
    bound_z_pos = np.vstack((bound_z_pos,bound_z_pos_more))

    ### domain points
    domain_pts1,_ = sampling_uniform(2.,
                                     [x_min[0],x_min[1],x_min[2]],
                                     [x_max[0],x_max[1],x_max[2]-3.],'domain',t)

    domain_pts2,_ = sampling_uniform(1.,
                                     [x_min[0],x_min[1],x_max[2]-3.+.5],
                                     [x_max[0],x_max[1],x_max[2]-1.],'domain',t)

    domain_pts3 = []
    for ti in t:
        di,_ = sampling_uniform(.5,
                                [x_min[0],x_min[1],x_max[2]-1.+.25,],
                                [x_max[0],x_max[1],x_max[2]],'domain',[ti])
        domain_pts3.append(di)
    domain_pts3 = np.vstack(domain_pts3)
    domain_pts = np.vstack((domain_pts1,domain_pts2,domain_pts3))

    # initial points
    init_pts1,_ = sampling_uniform(2.,[x_min[0],x_min[1],x_min[2]],
                                   [x_max[0],x_max[1],x_max[2]],'domain',[0],e=0)
    # more points near the toolpath origin
    init_pts2,_ = sampling_uniform(.5,[x0-2,y0-2,x_max[2]-2],
                                   [x0+2,y0+2,x_max[2]],'domain',[0])
    
    init_pts = np.vstack((init_pts1,init_pts2))
    

    p.extend([torch.tensor(bound_x_neg,requires_grad=True,dtype=torch.float).to(device),
              torch.tensor(bound_x_pos,requires_grad=True,dtype=torch.float).to(device),
              torch.tensor(bound_y_neg,requires_grad=True,dtype=torch.float).to(device),
              torch.tensor(bound_y_pos,requires_grad=True,dtype=torch.float).to(device),
              torch.tensor(bound_z_neg,requires_grad=True,dtype=torch.float).to(device),
              torch.tensor(bound_z_pos,requires_grad=True,dtype=torch.float).to(device),
              torch.tensor(init_pts,requires_grad=True,dtype=torch.float).to(device),
              torch.tensor(domain_pts,requires_grad=True,dtype=torch.float).to(device)])
    f.extend([['BC','-x'],['BC','+x'],['BC','-y'],['BC','+y'],['BC','-z'],['BC','+z'],['IC',T_ref],['domain']])
    
    return p,f

# %%
def BC(x,y,z,t,net,loc):
    X = torch.cat([x,y,z,t],axis=-1)
    T = net(X)
    if loc == '-x':
        T_x = grad(T,x,create_graph=True,grad_outputs=torch.ones_like(T))[0]
        return k*T_x - h*(T-T_ref) - Rboltz*emiss*(T**4-T_ref**4)
    if loc == '+x':
        T_x = grad(T,x,create_graph=True,grad_outputs=torch.ones_like(T))[0]
        return -k*T_x - h*(T-T_ref) - Rboltz*emiss*(T**4-T_ref**4)
    if loc == '-y':
        T_y = grad(T,y,create_graph=True,grad_outputs=torch.ones_like(T))[0]
        return k*T_y - h*(T-T_ref) - Rboltz*emiss*(T**4-T_ref**4)
    if loc == '+y':
        T_y = grad(T,y,create_graph=True,grad_outputs=torch.ones_like(T))[0]
        return -k*T_y - h*(T-T_ref) - Rboltz*emiss*(T**4-T_ref**4)
    if loc == '-z':
        T_t = grad(T,t,create_graph=True,grad_outputs=torch.ones_like(T))[0]
        return T_t
    if loc == '+z':
        T_z = grad(T,z,create_graph=True,grad_outputs=torch.ones_like(T))[0]
        q = 2*P*eta/3.14159265/r**2*torch.exp(-2*(torch.square(x-x0-v*t)+torch.square(y-y0))/r**2)*(t<=t_end)*(t>0)
        return -k*T_z - h*(T-T_ref) - Rboltz*emiss*(T**4-T_ref**4) + q

# %%
def output_transform(X):
    X = T_range*nn.Softplus()(X)+ T_ref
    return X


def input_transform(X):
    X = 2.*(X-X_min)/(X_max-X_min) - 1.
    return X

# %%
import torch
import torch.nn as nn
from torch.autograd import grad
import numpy as np
import time
import matplotlib.pyplot as plt

# Define the plotting functions
def plot_points_2D(point_sets, flags, filename="2D_top_surface.png"):
    plt.figure(figsize=(10, 8))
    markers = {'domain': 'o', 'BC': 'x', 'IC': 's'}
    colors = {'domain': 'blue', 'BC': 'red', 'IC': 'green'}
    
    for points, flag in zip(point_sets, flags):
        points = points.detach().cpu().numpy()
        label = f"{flag[0]} {flag[1]}" if flag[0] == 'BC' else flag[0]
        plt.scatter(points[:, 0], points[:, 1], c=colors[flag[0]], marker=markers[flag[0]], label=label, s=1)

    handles, labels = plt.gca().get_legend_handles_labels()
    by_label = dict(zip(labels, handles))
    plt.legend(by_label.values(), by_label.keys())

    plt.xlabel('x')
    plt.ylabel('y')
    plt.title('2D Top Surface')
    plt.savefig(filename)
    plt.close()

def plot_points_3D(point_sets, flags, filename="3D_domain.png"):
    fig = plt.figure(figsize=(15, 12), dpi=300)
    ax = fig.add_subplot(111, projection='3d')
    markers = {'domain': 'o', 'BC': 'x', 'IC': 's'}
    colors = {
        'domain': 'blue', 
        'BC': 'red', 
        'IC': 'green', 
        'BC -x': 'cyan', 
        'BC +x': 'magenta', 
        'BC -y': 'yellow', 
        'BC +y': 'black', 
        'BC -z': 'purple', 
        'BC +z': 'orange'
    }
    
    for points, flag in zip(point_sets, flags):
        points = points.detach().cpu().numpy()
        label = f"{flag[0]} {flag[1]}" if flag[0] == 'BC' else flag[0]
        ax.scatter(points[:, 0], points[:, 1], points[:, 2], c=colors.get(label, 'blue'), marker=markers[flag[0]], label=label, s=20, alpha=0.6)

    handles, labels = ax.get_legend_handles_labels()
    by_label = dict(zip(labels, handles))
    ax.legend(by_label.values(), by_label.keys(), loc='best', fontsize='small')

    ax.set_xlabel('x', fontsize=12)
    ax.set_ylabel('y', fontsize=12)
    ax.set_zlabel('z', fontsize=12)
    ax.set_title('3D Scatter Plot of Points in the Domain', fontsize=15)

    xlim = ax.get_xlim3d()
    ylim = ax.get_ylim3d()
    zlim = ax.get_zlim3d()
    ax.set_box_aspect([xlim[1] - xlim[0], ylim[1] - ylim[0], zlim[1] - zlim[0]])

    plt.savefig(filename, bbox_inches='tight', pad_inches=0.1)
    plt.close()

def plot_loss_curves(l_history, filename="loss_curves.png"):
    l_history = np.array(l_history)
    plt.figure(figsize=(10, 8))
    plt.plot(l_history[:, 0], label='Total Loss')
    plt.plot(l_history[:, 1], label='BC Loss')
    plt.plot(l_history[:, 2], label='IC Loss')
    plt.plot(l_history[:, 3], label='PDE Loss')
    plt.yscale('log')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.title('Loss Curves')
    plt.legend()
    plt.savefig(filename)
    plt.close()

def plot_predictions_3D(net, X_min, X_max, T_range, T_ref, epoch, filename="predictions_3D.png"):
    x = np.linspace(X_min.cpu().numpy()[0], X_max.cpu().numpy()[0], 50)
    y = np.linspace(X_min.cpu().numpy()[1], X_max.cpu().numpy()[1], 50)
    z = np.linspace(X_min.cpu().numpy()[2], X_max.cpu().numpy()[2], 50)
    t_vals = [0, 1, 2, 3]

    fig = plt.figure(figsize=(20, 15), dpi=300)

    for i, t in enumerate(t_vals):
        ax = fig.add_subplot(2, 2, i + 1, projection='3d')
        X, Y, Z = np.meshgrid(x, y, z)
        points = np.stack([X.ravel(), Y.ravel(), Z.ravel(), np.full_like(X.ravel(), t)], axis=-1)
        points = torch.tensor(points, dtype=torch.float32).to(next(net.parameters()).device)
        predictions = net(points).detach().cpu().numpy().reshape(50, 50, 50)

        sc = ax.scatter(X, Y, Z, c=predictions.ravel(), cmap='jet', marker='o', s=20, alpha=0.6)
        cbar = fig.colorbar(sc, ax=ax, label='U(t,x,y,z)')
        cbar.ax.tick_params(labelsize=12)
        ax.set_title(f"Time: {t}", fontsize=15)
        ax.set_xlabel('x', fontsize=12)
        ax.set_ylabel('y', fontsize=12)
        ax.set_zlabel('z', fontsize=12)

        xlim = ax.get_xlim3d()
        ylim = ax.get_ylim3d()
        zlim = ax.get_zlim3d()
        ax.set_box_aspect([xlim[1] - xlim[0], ylim[1] - ylim[0], zlim[1] - zlim[0]])

    plt.suptitle(f"3D Predictions at Epoch {epoch}", fontsize=18)
    plt.tight_layout()
    plt.savefig(filename, bbox_inches='tight', pad_inches=0.1)
    plt.close()

# PDE definition
def PDE(x, y, z, t, net):
    """
    Define the PDE for the problem.
    """
    X = torch.cat([x, y, z, t], axis=-1)
    T = net(X)

    T_t = grad(T, t, create_graph=True, grad_outputs=torch.ones_like(T))[0]
    T_x = grad(T, x, create_graph=True, grad_outputs=torch.ones_like(T))[0]
    T_xx = grad(T_x, x, create_graph=True, grad_outputs=torch.ones_like(T_x))[0]

    T_y = grad(T, y, create_graph=True, grad_outputs=torch.ones_like(T))[0]
    T_yy = grad(T_y, y, create_graph=True, grad_outputs=torch.ones_like(T_y))[0]

    T_z = grad(T, z, create_graph=True, grad_outputs=torch.ones_like(T))[0]
    T_zz = grad(T_z, z, create_graph=True, grad_outputs=torch.ones_like(T_z))[0]

    f = rho * Cp * T_t - k * (T_xx + T_yy + T_zz)
    return f

# Generate points for training
def generate_points(p=[], f=[]):
    """
    Generate points for the domain and boundary conditions.
    """
    t = np.linspace(x_min[3] + 0.01, x_max[3], 61)

    # Boundary points
    bound_x_neg, _ = sampling_uniform(1., x_min, x_max, '-x', t)
    bound_x_pos, _ = sampling_uniform(1., x_min, x_max, '+x', t)
    bound_y_neg, _ = sampling_uniform(1., x_min, x_max, '-y', t)
    bound_y_pos, _ = sampling_uniform(1., x_min, x_max, '+y', t)
    bound_z_neg, _ = sampling_uniform(1., x_min, x_max, '-z', t)
    bound_z_pos, _ = sampling_uniform(1., x_min, x_max, '+z', t)

    bound_z_pos_more = []
    for ti in t:
        if ti <= t_end:
            zi, _ = sampling_uniform(.25,
                                     [max(x0 + ti * v - 2 * r, x_min[0]), max(x_min[1], y0 - 2 * r), x_min[2]],
                                     [min(x0 + ti * v + 2 * r, x_max[0]), min(x_max[1], y0 + 2 * r), x_max[2]],
                                     '+z', [ti])
            bound_z_pos_more.append(zi)

    bound_z_pos_more = np.vstack(bound_z_pos_more)
    bound_z_pos = np.vstack((bound_z_pos, bound_z_pos_more))

    # Domain points
    domain_pts1, _ = sampling_uniform(2., [x_min[0], x_min[1], x_min[2]], [x_max[0], x_max[1], x_max[2] - 3.], 'domain', t)
    domain_pts2, _ = sampling_uniform(1., [x_min[0], x_min[1], x_max[2] - 3. + .5], [x_max[0], x_max[1], x_max[2] - 1.], 'domain', t)

    domain_pts3 = []
    for ti in t:
        di, _ = sampling_uniform(.5, [x_min[0], x_min[1], x_max[2] - 1. + .25], [x_max[0], x_max[1], x_max[2]], 'domain', [ti])
        domain_pts3.append(di)
    domain_pts3 = np.vstack(domain_pts3)
    domain_pts = np.vstack((domain_pts1, domain_pts2, domain_pts3))

    # Initial points
    init_pts1, _ = sampling_uniform(2., [x_min[0], x_min[1], x_min[2]], [x_max[0], x_max[1], x_max[2]], 'domain', [0], e=0)
    init_pts2, _ = sampling_uniform(.5, [x0 - 2, y0 - 2, x_max[2] - 2], [x0 + 2, y0 + 2, x_max[2]], 'domain', [0])

    init_pts = np.vstack((init_pts1, init_pts2))

    p.extend([torch.tensor(bound_x_neg, requires_grad=True, dtype=torch.float).to(device),
              torch.tensor(bound_x_pos, requires_grad=True, dtype=torch.float).to(device),
              torch.tensor(bound_y_neg, requires_grad=True, dtype=torch.float).to(device),
              torch.tensor(bound_y_pos, requires_grad=True, dtype=torch.float).to(device),
              torch.tensor(bound_z_neg, requires_grad=True, dtype=torch.float).to(device),
              torch.tensor(bound_z_pos, requires_grad=True, dtype=torch.float).to(device),
              torch.tensor(init_pts, requires_grad=True, dtype=torch.float).to(device),
              torch.tensor(domain_pts, requires_grad=True, dtype=torch.float).to(device)])
    f.extend([['BC', '-x'], ['BC', '+x'], ['BC', '-y'], ['BC', '+y'], ['BC', '-z'], ['BC', '+z'], ['IC', T_ref], ['domain']])
    
    return p, f

# Boundary condition function
def BC(x, y, z, t, net, loc):
    """
    Define the boundary condition for the problem.
    """
    X = torch.cat([x, y, z, t], axis=-1)
    T = net(X)
    if loc == '-x':
        T_x = grad(T, x, create_graph=True, grad_outputs=torch.ones_like(T))[0]
        return k * T_x - h * (T - T_ref) - Rboltz * emiss * (T**4 - T_ref**4)
    elif loc == '+x':
        T_x = grad(T, x, create_graph=True, grad_outputs=torch.ones_like(T))[0]
        return -k * T_x - h * (T - T_ref) - Rboltz * emiss * (T**4 - T_ref**4)
    elif loc == '-y':
        T_y = grad(T, y, create_graph=True, grad_outputs=torch.ones_like(T))[0]
        return k * T_y - h * (T - T_ref) - Rboltz * emiss * (T**4 - T_ref**4)
    elif loc == '+y':
        T_y = grad(T, y, create_graph=True, grad_outputs=torch.ones_like(T))[0]
        return -k * T_y - h * (T - T_ref) - Rboltz * emiss * (T**4 - T_ref**4)
    elif loc == '-z':
        T_t = grad(T, t, create_graph=True, grad_outputs=torch.ones_like(T))[0]
        return T_t
    elif loc == '+z':
        T_z = grad(T, z, create_graph=True, grad_outputs=torch.ones_like(T))[0]
        q = 2 * P * eta / np.pi / r**2 * torch.exp(-2 * (torch.square(x - x0 - v * t) + torch.square(y - y0)) / r**2) * (t <= t_end) * (t > 0)
        return -k * T_z - h * (T - T_ref) - Rboltz * emiss * (T**4 - T_ref**4) + q

# Output transformation function
def output_transform(X):
    return T_range * nn.Softplus()(X) + T_ref

# Input transformation function
def input_transform(X):
    return 2. * (X - X_min) / (X_max - X_min) - 1.

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# Domain
x_max = np.array([40., 10., 6., 3.])
x_min = np.array([0., 0., 0., 0.])
X_max = torch.tensor(x_max, dtype=torch.float).to(device)
X_min = torch.tensor(x_min, dtype=torch.float).to(device)

# Laser parameters
x0 = 5.
y0 = 5.
r = 1.5
v = 10. 
t_end = 3.
P = 500.
eta = .4

# Ambient temperature and max temperature range
T_ref = 298.
T_range = 3000.

# Material parameters
Cp = .5
k = .01
h = 2e-5
Rboltz = 5.6704e-14
emiss = .3
rho = 8e-3

# Network definition
net = FNN([4, 100, 100, 100, 1], nn.Tanh(), in_tf=input_transform, out_tf=output_transform)
net.to(device)

# Generate points and flags
point_sets, flags = generate_points([], [])

# Plot initial points
plot_points_2D(point_sets, flags, filename="/home/am23mtech11006/AM23MTECH11006/Physics informed_laser/2d_3d_domain_plotting/2D_top_surface_initial.png")
plot_points_3D(point_sets, flags, filename="/home/am23mtech11006/AM23MTECH11006/Physics informed_laser/2d_3d_domain_plotting/3D_domain_initial.png")

# Define optimizer
optimizer = torch.optim.Adam(net.parameters(), lr=2e-4)

# Training parameters
iterations = 50000
info_num = 100
w = [2., 1., 1., 1.]  # Define the weights

n_bc = sum([points.shape[0] for points, flag in zip(point_sets, flags) if flag[0] == 'BC'])
n_ic = sum([points.shape[0] for points, flag in zip(point_sets, flags) if flag[0] == 'IC'])
n_PDE = sum([points.shape[0] for points, flag in zip(point_sets, flags) if flag[0] == 'domain'])

# Train the network
l_history = []
err_history = []
for epoch in range(iterations):
    net.train()
    optimizer.zero_grad()
    l_BC = l_IC = l_PDE = 0

    for points, flag in zip(point_sets, flags):
        if flag[0] == 'BC':
            f = BC(points[:, 0:1], points[:, 1:2], points[:, 2:3], points[:, 3:4], net, flag[1])
            l_BC += loss(f) * points.shape[0] / n_bc
        elif flag[0] == 'IC':
            pred = net(points)
            l_IC += loss(pred, flag[1]) * points.shape[0] / n_ic
        elif flag[0] == 'domain':
            f = PDE(points[:, 0:1], points[:, 1:2], points[:, 2:3], points[:, 3:4], net)
            l_PDE += loss(f) * points.shape[0] / n_PDE

    cost = (w[0] * l_BC + w[1] * l_IC + w[2] * l_PDE) / 3  # weighted
    l_history.append([cost.item(), l_BC.item(), l_IC.item(), l_PDE.item()])

    cost.backward()
    optimizer.step()

    # Print all types of losses in the console after every epoch
    # Print all types of losses in the console every 100 epochs
    if epoch % 100 == 0:
        print(f"Epoch {epoch}: Total Loss = {cost.item():.4e}, BC Loss = {l_BC.item():.4e}, IC Loss = {l_IC.item():.4e}, PDE Loss = {l_PDE.item():.4e}")

    # Save the model, loss curves, and plot predictions every 1000 epochs
    if epoch % 1000 == 0:
        torch.save(net.state_dict(), f'/home/am23mtech11006/AM23MTECH11006/Physics informed_laser/models/model_epoch_{epoch}.pt')
        np.save(f'/home/am23mtech11006/AM23MTECH11006/Physics informed_laser/loss_history_epoch_{epoch}.npy', l_history)
        plot_loss_curves(l_history, filename=f"/home/am23mtech11006/AM23MTECH11006/Physics informed_laser/loss_history/loss_curves_epoch_{epoch}.png")
        plot_predictions_3D(net, X_min, X_max, T_range, T_ref, epoch, filename=f"/home/am23mtech11006/AM23MTECH11006/Physics informed_laser/results_prediction_3d_plots/predictions_3D_epoch_{epoch}.png")

# Save the final trained model and loss history
torch.save(net.state_dict(), '/home/am23mtech11006/AM23MTECH11006/Physics informed_laser/models/no_auxiliary_data.pt')
np.save('/home/am23mtech11006/AM23MTECH11006/Physics informed_laser/models/no_auxiliary_data_loss.npy', l_history)
plot_loss_curves(l_history, filename="/home/am23mtech11006/AM23MTECH11006/Physics informed_laser/loss_history/loss_curves_final.png")
# Out:
# Epoch 0: Total Loss = 2.0586e+06, BC Loss = 6.3203e+03, IC Loss = 6.1632e+06, PDE Loss = 5.8997e-01
# Epoch 100: Total Loss = 1.8564e+05, BC Loss = 1.3398e+05, IC Loss = 2.8894e+05, PDE Loss = 2.4728e+01
# Epoch 200: Total Loss = 6.3677e+04, BC Loss = 4.5901e+04, IC Loss = 9.9200e+04, PDE Loss = 2.9691e+01
# Epoch 300: Total Loss = 1.7743e+04, BC Loss = 1.2530e+04, IC Loss = 2.8140e+04, PDE Loss = 3.1001e+01
# Epoch 400: Total Loss = 6.7726e+03, BC Loss = 4.7777e+03, IC Loss = 1.0733e+04, PDE Loss = 2.9665e+01
# Epoch 500: Total Loss = 3.4394e+03, BC Loss = 2.4470e+03, IC Loss = 5.3967e+03, PDE Loss = 2.7260e+01
# Epoch 600: Total Loss = 2.0724e+03, BC Loss = 1.4933e+03, IC Loss = 3.2062e+03, PDE Loss = 2.4561e+01
# Epoch 700: Total Loss = 1.3884e+03, BC Loss = 1.0149e+03, IC Loss = 2.1133e+03, PDE Loss = 2.1884e+01
# Epoch 800: Total Loss = 9.9804e+02, BC Loss = 7.4084e+02, IC Loss = 1.4931e+03, PDE Loss = 1.9363e+01
# Epoch 900: Total Loss = 7.5412e+02, BC Loss = 5.6861e+02, IC Loss = 1.1081e+03, PDE Loss = 1.7054e+01
# Epoch 1000: Total Loss = 5.9130e+02, BC Loss = 4.5296e+02, IC Loss = 8.5299e+02, PDE Loss = 1.4973e+01
# Epoch 1100: Total Loss = 4.7704e+02, BC Loss = 3.7132e+02, IC Loss = 6.7538e+02, PDE Loss = 1.3116e+01
# Epoch 1200: Total Loss = 3.9369e+02, BC Loss = 3.1140e+02, IC Loss = 5.4681e+02, PDE Loss = 1.1470e+01
# Epoch 1300: Total Loss = 3.3097e+02, BC Loss = 2.6604e+02, IC Loss = 4.5080e+02, PDE Loss = 1.0019e+01
# Epoch 1400: Total Loss = 2.8255e+02, BC Loss = 2.3083e+02, IC Loss = 3.7724e+02, PDE Loss = 8.7424e+00
# Epoch 1500: Total Loss = 2.4438e+02, BC Loss = 2.0293e+02, IC Loss = 3.1967e+02, PDE Loss = 7.6233e+00
# Epoch 1600: Total Loss = 2.1376e+02, BC Loss = 1.8042e+02, IC Loss = 2.7379e+02, PDE Loss = 6.6439e+00
# Epoch 1700: Total Loss = 1.8881e+02, BC Loss = 1.6199e+02, IC Loss = 2.3666e+02, PDE Loss = 5.7881e+00
# Epoch 1800: Total Loss = 1.6822e+02, BC Loss = 1.4671e+02, IC Loss = 2.0620e+02, PDE Loss = 5.0413e+00
# Epoch 1900: Total Loss = 1.5104e+02, BC Loss = 1.3390e+02, IC Loss = 1.8092e+02, PDE Loss = 4.3904e+00
# Epoch 2000: Total Loss = 1.3656e+02, BC Loss = 1.2306e+02, IC Loss = 1.5973e+02, PDE Loss = 3.8235e+00
# Epoch 2100: Total Loss = 1.2424e+02, BC Loss = 1.1380e+02, IC Loss = 1.4180e+02, PDE Loss = 3.3302e+00
# Epoch 2200: Total Loss = 1.1369e+02, BC Loss = 1.0584e+02, IC Loss = 1.2650e+02, PDE Loss = 2.9013e+00
# Epoch 2300: Total Loss = 1.0460e+02, BC Loss = 9.8953e+01, IC Loss = 1.1335e+02, PDE Loss = 2.5285e+00
# Epoch 2400: Total Loss = 9.6699e+01, BC Loss = 9.2955e+01, IC Loss = 1.0198e+02, PDE Loss = 2.2046e+00
# Epoch 2500: Total Loss = 8.9809e+01, BC Loss = 8.7708e+01, IC Loss = 9.2087e+01, PDE Loss = 1.9234e+00
# Epoch 2600: Total Loss = 8.3766e+01, BC Loss = 8.3095e+01, IC Loss = 8.3429e+01, PDE Loss = 1.6791e+00
# Epoch 2700: Total Loss = 7.8444e+01, BC Loss = 7.9025e+01, IC Loss = 7.5816e+01, PDE Loss = 1.4670e+00
# Epoch 2800: Total Loss = 7.3737e+01, BC Loss = 7.5419e+01, IC Loss = 6.9091e+01, PDE Loss = 1.2828e+00
# Epoch 2900: Total Loss = 6.9559e+01, BC Loss = 7.2215e+01, IC Loss = 6.3124e+01, PDE Loss = 1.1228e+00
# Epoch 3000: Total Loss = 6.5838e+01, BC Loss = 6.9359e+01, IC Loss = 5.7811e+01, PDE Loss = 9.8380e-01
# Epoch 3100: Total Loss = 6.2513e+01, BC Loss = 6.6806e+01, IC Loss = 5.3062e+01, PDE Loss = 8.6291e-01
# Epoch 3200: Total Loss = 5.9533e+01, BC Loss = 6.4520e+01, IC Loss = 4.8803e+01, PDE Loss = 7.5774e-01
# Epoch 3300: Total Loss = 5.6857e+01, BC Loss = 6.2466e+01, IC Loss = 4.4971e+01, PDE Loss = 6.6618e-01
# Epoch 3400: Total Loss = 5.4446e+01, BC Loss = 6.0619e+01, IC Loss = 4.1514e+01, PDE Loss = 5.8639e-01
# Epoch 3500: Total Loss = 5.2270e+01, BC Loss = 5.8953e+01, IC Loss = 3.8386e+01, PDE Loss = 5.1681e-01
# Epoch 3600: Total Loss = 5.0301e+01, BC Loss = 5.7449e+01, IC Loss = 3.5549e+01, PDE Loss = 4.5606e-01
# Epoch 3700: Total Loss = 4.8516e+01, BC Loss = 5.6088e+01, IC Loss = 3.2970e+01, PDE Loss = 4.0296e-01
# Epoch 3800: Total Loss = 4.6895e+01, BC Loss = 5.4855e+01, IC Loss = 3.0619e+01, PDE Loss = 3.5650e-01
# Epoch 3900: Total Loss = 4.5421e+01, BC Loss = 5.3737e+01, IC Loss = 2.8473e+01, PDE Loss = 3.1579e-01
# Epoch 4000: Total Loss = 4.4077e+01, BC Loss = 5.2721e+01, IC Loss = 2.6508e+01, PDE Loss = 2.8008e-01
# Epoch 4100: Total Loss = 4.2850e+01, BC Loss = 5.1796e+01, IC Loss = 2.4708e+01, PDE Loss = 2.4870e-01
# Epoch 4200: Total Loss = 4.1728e+01, BC Loss = 5.0954e+01, IC Loss = 2.3054e+01, PDE Loss = 2.2109e-01
# Epoch 4300: Total Loss = 4.0701e+01, BC Loss = 5.0187e+01, IC Loss = 2.1533e+01, PDE Loss = 1.9677e-01
# Epoch 4400: Total Loss = 3.9759e+01, BC Loss = 4.9486e+01, IC Loss = 2.0131e+01, PDE Loss = 1.7531e-01
# Epoch 4500: Total Loss = 3.8895e+01, BC Loss = 4.8845e+01, IC Loss = 1.8838e+01, PDE Loss = 1.5635e-01
# Epoch 4600: Total Loss = 3.8100e+01, BC Loss = 4.8259e+01, IC Loss = 1.7643e+01, PDE Loss = 1.3957e-01
# Epoch 4700: Total Loss = 3.7369e+01, BC Loss = 4.7722e+01, IC Loss = 1.6537e+01, PDE Loss = 1.2469e-01
# Epoch 4800: Total Loss = 3.6695e+01, BC Loss = 4.7230e+01, IC Loss = 1.5513e+01, PDE Loss = 1.1149e-01
# Epoch 4900: Total Loss = 3.6073e+01, BC Loss = 4.6779e+01, IC Loss = 1.4562e+01, PDE Loss = 9.9755e-02
# Epoch 5000: Total Loss = 3.5499e+01, BC Loss = 4.6365e+01, IC Loss = 1.3680e+01, PDE Loss = 8.9307e-02
# Epoch 5100: Total Loss = 3.4969e+01, BC Loss = 4.5984e+01, IC Loss = 1.2859e+01, PDE Loss = 7.9995e-02
# Epoch 5200: Total Loss = 3.4478e+01, BC Loss = 4.5633e+01, IC Loss = 1.2096e+01, PDE Loss = 7.1679e-02
# Epoch 5300: Total Loss = 3.4024e+01, BC Loss = 4.5311e+01, IC Loss = 1.1385e+01, PDE Loss = 6.4247e-02
# Epoch 5400: Total Loss = 3.3602e+01, BC Loss = 4.5014e+01, IC Loss = 1.0722e+01, PDE Loss = 5.7594e-02
# Epoch 5500: Total Loss = 3.3211e+01, BC Loss = 4.4740e+01, IC Loss = 1.0103e+01, PDE Loss = 5.1630e-02
# Epoch 5600: Total Loss = 3.2848e+01, BC Loss = 4.4487e+01, IC Loss = 9.5256e+00, PDE Loss = 4.6279e-02
# Epoch 5700: Total Loss = 3.2511e+01, BC Loss = 4.4253e+01, IC Loss = 8.9855e+00, PDE Loss = 4.1474e-02
# Epoch 5800: Total Loss = 3.2197e+01, BC Loss = 4.4037e+01, IC Loss = 8.4803e+00, PDE Loss = 3.7152e-02
# Epoch 5900: Total Loss = 3.1905e+01, BC Loss = 4.3837e+01, IC Loss = 8.0074e+00, PDE Loss = 3.3262e-02
# Epoch 6000: Total Loss = 3.1633e+01, BC Loss = 4.3653e+01, IC Loss = 7.5644e+00, PDE Loss = 2.9760e-02
# Epoch 6100: Total Loss = 3.1380e+01, BC Loss = 4.3481e+01, IC Loss = 7.1492e+00, PDE Loss = 2.6604e-02
# Epoch 6200: Total Loss = 3.1143e+01, BC Loss = 4.3323e+01, IC Loss = 6.7597e+00, PDE Loss = 2.3760e-02
# Epoch 6300: Total Loss = 3.0922e+01, BC Loss = 4.3175e+01, IC Loss = 6.3942e+00, PDE Loss = 2.1198e-02
# Epoch 6400: Total Loss = 3.0716e+01, BC Loss = 4.3039e+01, IC Loss = 6.0508e+00, PDE Loss = 1.8890e-02
# Epoch 6500: Total Loss = 3.0523e+01, BC Loss = 4.2912e+01, IC Loss = 5.7282e+00, PDE Loss = 1.6813e-02
# Epoch 6600: Total Loss = 3.0342e+01, BC Loss = 4.2793e+01, IC Loss = 5.4248e+00, PDE Loss = 1.4947e-02
# Epoch 6700: Total Loss = 3.0173e+01, BC Loss = 4.2684e+01, IC Loss = 5.1393e+00, PDE Loss = 1.3274e-02
# Epoch 6800: Total Loss = 3.0015e+01, BC Loss = 4.2581e+01, IC Loss = 4.8706e+00, PDE Loss = 1.1777e-02
# Epoch 6900: Total Loss = 2.9867e+01, BC Loss = 4.2486e+01, IC Loss = 4.6176e+00, PDE Loss = 1.0443e-02
# Epoch 7000: Total Loss = 2.9728e+01, BC Loss = 4.2397e+01, IC Loss = 4.3792e+00, PDE Loss = 9.2618e-03
# Epoch 7100: Total Loss = 2.9597e+01, BC Loss = 4.2315e+01, IC Loss = 4.1544e+00, PDE Loss = 8.2222e-03
# Epoch 7200: Total Loss = 2.9475e+01, BC Loss = 4.2237e+01, IC Loss = 3.9423e+00, PDE Loss = 7.3159e-03
# Epoch 7300: Total Loss = 2.9360e+01, BC Loss = 4.2165e+01, IC Loss = 3.7421e+00, PDE Loss = 6.5359e-03
# Epoch 7400: Total Loss = 2.9252e+01, BC Loss = 4.2098e+01, IC Loss = 3.5530e+00, PDE Loss = 5.8758e-03
# Epoch 7500: Total Loss = 2.9150e+01, BC Loss = 4.2035e+01, IC Loss = 3.3744e+00, PDE Loss = 5.3303e-03
# Epoch 7600: Total Loss = 2.9054e+01, BC Loss = 4.1976e+01, IC Loss = 3.2056e+00, PDE Loss = 4.8951e-03
# Epoch 7700: Total Loss = 2.8964e+01, BC Loss = 4.1921e+01, IC Loss = 3.0460e+00, PDE Loss = 4.5662e-03
# Epoch 7800: Total Loss = 2.8880e+01, BC Loss = 4.1870e+01, IC Loss = 2.8949e+00, PDE Loss = 4.3402e-03
# Epoch 7900: Total Loss = 2.8800e+01, BC Loss = 4.1822e+01, IC Loss = 2.7520e+00, PDE Loss = 4.2144e-03
# Epoch 8000: Total Loss = 2.8725e+01, BC Loss = 4.1778e+01, IC Loss = 2.6165e+00, PDE Loss = 4.1859e-03
# Epoch 8100: Total Loss = 2.8655e+01, BC Loss = 4.1736e+01, IC Loss = 2.4882e+00, PDE Loss = 4.2523e-03
# Epoch 8200: Total Loss = 2.8588e+01, BC Loss = 4.1697e+01, IC Loss = 2.3666e+00, PDE Loss = 4.4109e-03
# Epoch 8300: Total Loss = 2.8526e+01, BC Loss = 4.1661e+01, IC Loss = 2.2513e+00, PDE Loss = 4.6590e-03
# Epoch 8400: Total Loss = 2.8467e+01, BC Loss = 4.1627e+01, IC Loss = 2.1420e+00, PDE Loss = 4.9938e-03
# Epoch 8500: Total Loss = 2.8411e+01, BC Loss = 4.1595e+01, IC Loss = 2.0383e+00, PDE Loss = 5.4127e-03
# Epoch 8600: Total Loss = 2.8359e+01, BC Loss = 4.1566e+01, IC Loss = 1.9400e+00, PDE Loss = 5.9126e-03
# Epoch 8700: Total Loss = 2.8310e+01, BC Loss = 4.1538e+01, IC Loss = 1.8466e+00, PDE Loss = 6.4903e-03
# Epoch 8800: Total Loss = 2.8264e+01, BC Loss = 4.1513e+01, IC Loss = 1.7581e+00, PDE Loss = 7.1429e-03
# Epoch 8900: Total Loss = 2.8220e+01, BC Loss = 4.1489e+01, IC Loss = 1.6741e+00, PDE Loss = 7.8673e-03
# Epoch 9000: Total Loss = 2.8179e+01, BC Loss = 4.1467e+01, IC Loss = 1.5944e+00, PDE Loss = 8.6594e-03
# Epoch 9100: Total Loss = 2.8140e+01, BC Loss = 4.1447e+01, IC Loss = 1.5188e+00, PDE Loss = 9.5165e-03
# Epoch 9200: Total Loss = 2.8104e+01, BC Loss = 4.1428e+01, IC Loss = 1.4470e+00, PDE Loss = 1.0436e-02
# Epoch 9300: Total Loss = 2.8070e+01, BC Loss = 4.1410e+01, IC Loss = 1.3790e+00, PDE Loss = 1.1415e-02
# Epoch 9400: Total Loss = 2.8038e+01, BC Loss = 4.1393e+01, IC Loss = 1.3145e+00, PDE Loss = 1.2450e-02
# Epoch 9500: Total Loss = 2.8008e+01, BC Loss = 4.1378e+01, IC Loss = 1.2534e+00, PDE Loss = 1.3539e-02
# Epoch 9600: Total Loss = 2.7979e+01, BC Loss = 4.1364e+01, IC Loss = 1.1954e+00, PDE Loss = 1.4679e-02
# Epoch 9700: Total Loss = 2.7953e+01, BC Loss = 4.1351e+01, IC Loss = 1.1405e+00, PDE Loss = 1.5868e-02
# Epoch 9800: Total Loss = 2.7928e+01, BC Loss = 4.1339e+01, IC Loss = 1.0884e+00, PDE Loss = 1.7104e-02
# Epoch 9900: Total Loss = 2.7904e+01, BC Loss = 4.1327e+01, IC Loss = 1.0391e+00, PDE Loss = 1.8386e-02
# Epoch 10000: Total Loss = 2.7882e+01, BC Loss = 4.1317e+01, IC Loss = 9.9242e-01, PDE Loss = 1.9710e-02
# Epoch 10100: Total Loss = 2.7861e+01, BC Loss = 4.1307e+01, IC Loss = 9.4816e-01, PDE Loss = 2.1075e-02
# Epoch 10200: Total Loss = 2.7842e+01, BC Loss = 4.1298e+01, IC Loss = 9.0623e-01, PDE Loss = 2.2480e-02
# Epoch 10300: Total Loss = 2.7823e+01, BC Loss = 4.1290e+01, IC Loss = 8.6652e-01, PDE Loss = 2.3922e-02
# Epoch 10400: Total Loss = 2.7806e+01, BC Loss = 4.1282e+01, IC Loss = 8.2890e-01, PDE Loss = 2.5400e-02
# Epoch 10500: Total Loss = 2.7790e+01, BC Loss = 4.1275e+01, IC Loss = 7.9326e-01, PDE Loss = 2.6910e-02
# Epoch 10600: Total Loss = 2.7775e+01, BC Loss = 4.1268e+01, IC Loss = 7.5950e-01, PDE Loss = 2.8453e-02
# Epoch 10700: Total Loss = 2.7761e+01, BC Loss = 4.1262e+01, IC Loss = 7.2753e-01, PDE Loss = 3.0027e-02
# Epoch 10800: Total Loss = 2.7747e+01, BC Loss = 4.1256e+01, IC Loss = 6.9725e-01, PDE Loss = 3.1627e-02
# Epoch 10900: Total Loss = 2.7735e+01, BC Loss = 4.1251e+01, IC Loss = 6.6857e-01, PDE Loss = 3.3256e-02
# Epoch 11000: Total Loss = 2.7723e+01, BC Loss = 4.1246e+01, IC Loss = 6.4142e-01, PDE Loss = 3.4910e-02
# Epoch 11100: Total Loss = 2.7712e+01, BC Loss = 4.1242e+01, IC Loss = 6.1570e-01, PDE Loss = 3.6588e-02
# Epoch 11200: Total Loss = 2.7702e+01, BC Loss = 4.1238e+01, IC Loss = 5.9135e-01, PDE Loss = 3.8285e-02
# Epoch 11300: Total Loss = 2.7692e+01, BC Loss = 4.1234e+01, IC Loss = 5.6828e-01, PDE Loss = 4.0002e-02
# Epoch 11400: Total Loss = 2.7683e+01, BC Loss = 4.1230e+01, IC Loss = 5.4643e-01, PDE Loss = 4.1737e-02
# Epoch 11500: Total Loss = 2.7675e+01, BC Loss = 4.1227e+01, IC Loss = 5.2575e-01, PDE Loss = 4.3489e-02
# Epoch 11600: Total Loss = 2.7667e+01, BC Loss = 4.1224e+01, IC Loss = 5.0617e-01, PDE Loss = 4.5254e-02
# Epoch 11700: Total Loss = 2.7659e+01, BC Loss = 4.1221e+01, IC Loss = 4.8763e-01, PDE Loss = 4.7032e-02
# Epoch 11800: Total Loss = 2.7652e+01, BC Loss = 4.1219e+01, IC Loss = 4.7008e-01, PDE Loss = 4.8820e-02
# Epoch 11900: Total Loss = 2.7646e+01, BC Loss = 4.1216e+01, IC Loss = 4.5348e-01, PDE Loss = 5.0617e-02
# Epoch 12000: Total Loss = 2.7639e+01, BC Loss = 4.1214e+01, IC Loss = 4.3775e-01, PDE Loss = 5.2420e-02
# Epoch 12100: Total Loss = 2.7634e+01, BC Loss = 4.1212e+01, IC Loss = 4.2289e-01, PDE Loss = 5.4228e-02
# Epoch 12200: Total Loss = 2.7628e+01, BC Loss = 4.1210e+01, IC Loss = 4.0882e-01, PDE Loss = 5.6038e-02
# Epoch 12300: Total Loss = 2.7623e+01, BC Loss = 4.1208e+01, IC Loss = 3.9552e-01, PDE Loss = 5.7850e-02
# Epoch 12400: Total Loss = 2.7618e+01, BC Loss = 4.1206e+01, IC Loss = 3.8296e-01, PDE Loss = 5.9660e-02
# Epoch 12500: Total Loss = 2.7613e+01, BC Loss = 4.1204e+01, IC Loss = 3.7109e-01, PDE Loss = 6.1466e-02
# Epoch 12600: Total Loss = 2.7609e+01, BC Loss = 4.1202e+01, IC Loss = 3.5987e-01, PDE Loss = 6.3266e-02
# Epoch 12700: Total Loss = 2.7605e+01, BC Loss = 4.1200e+01, IC Loss = 3.4929e-01, PDE Loss = 6.5058e-02
# Epoch 12800: Total Loss = 2.7601e+01, BC Loss = 4.1198e+01, IC Loss = 3.3931e-01, PDE Loss = 6.6838e-02
# Epoch 12900: Total Loss = 2.7597e+01, BC Loss = 4.1197e+01, IC Loss = 3.2989e-01, PDE Loss = 6.8606e-02
# Epoch 13000: Total Loss = 2.7594e+01, BC Loss = 4.1195e+01, IC Loss = 3.2104e-01, PDE Loss = 7.0359e-02
# Epoch 13100: Total Loss = 2.7590e+01, BC Loss = 4.1193e+01, IC Loss = 3.1270e-01, PDE Loss = 7.2094e-02
# Epoch 13200: Total Loss = 2.7587e+01, BC Loss = 4.1191e+01, IC Loss = 3.0487e-01, PDE Loss = 7.3806e-02
# Epoch 13300: Total Loss = 2.7583e+01, BC Loss = 4.1189e+01, IC Loss = 2.9751e-01, PDE Loss = 7.5494e-02
# Epoch 13400: Total Loss = 2.7580e+01, BC Loss = 4.1186e+01, IC Loss = 2.9061e-01, PDE Loss = 7.7154e-02
# Epoch 13500: Total Loss = 2.7577e+01, BC Loss = 4.1184e+01, IC Loss = 2.8416e-01, PDE Loss = 7.8783e-02
# Epoch 13600: Total Loss = 2.7574e+01, BC Loss = 4.1182e+01, IC Loss = 2.7813e-01, PDE Loss = 8.0379e-02
# Epoch 13700: Total Loss = 2.7571e+01, BC Loss = 4.1179e+01, IC Loss = 2.7250e-01, PDE Loss = 8.1937e-02
# Epoch 13800: Total Loss = 2.7568e+01, BC Loss = 4.1176e+01, IC Loss = 2.6727e-01, PDE Loss = 8.3455e-02
# Epoch 13900: Total Loss = 2.7565e+01, BC Loss = 4.1173e+01, IC Loss = 2.6242e-01, PDE Loss = 8.4930e-02
# Epoch 14000: Total Loss = 2.7561e+01, BC Loss = 4.1170e+01, IC Loss = 2.5794e-01, PDE Loss = 8.6358e-02
# Epoch 14100: Total Loss = 2.7558e+01, BC Loss = 4.1166e+01, IC Loss = 2.5380e-01, PDE Loss = 8.7736e-02
# Epoch 14200: Total Loss = 2.7555e+01, BC Loss = 4.1162e+01, IC Loss = 2.5001e-01, PDE Loss = 8.9061e-02
# Epoch 14300: Total Loss = 2.7551e+01, BC Loss = 4.1158e+01, IC Loss = 2.4655e-01, PDE Loss = 9.0329e-02
# Epoch 14400: Total Loss = 2.7548e+01, BC Loss = 4.1154e+01, IC Loss = 2.4342e-01, PDE Loss = 9.1539e-02
# Epoch 14500: Total Loss = 2.7544e+01, BC Loss = 4.1149e+01, IC Loss = 2.4059e-01, PDE Loss = 9.2687e-02
# Epoch 14600: Total Loss = 2.7540e+01, BC Loss = 4.1144e+01, IC Loss = 2.3807e-01, PDE Loss = 9.3770e-02
# Epoch 14700: Total Loss = 2.7536e+01, BC Loss = 4.1138e+01, IC Loss = 2.3585e-01, PDE Loss = 9.4788e-02
# Epoch 14800: Total Loss = 2.7531e+01, BC Loss = 4.1132e+01, IC Loss = 2.3392e-01, PDE Loss = 9.5740e-02
# Epoch 14900: Total Loss = 2.7526e+01, BC Loss = 4.1125e+01, IC Loss = 2.3228e-01, PDE Loss = 9.6622e-02
# Epoch 15000: Total Loss = 2.7521e+01, BC Loss = 4.1118e+01, IC Loss = 2.3092e-01, PDE Loss = 9.7436e-02
# Epoch 15100: Total Loss = 2.7516e+01, BC Loss = 4.1110e+01, IC Loss = 2.2984e-01, PDE Loss = 9.8183e-02
# Epoch 15200: Total Loss = 2.7510e+01, BC Loss = 4.1101e+01, IC Loss = 2.2904e-01, PDE Loss = 9.8863e-02
# Epoch 15300: Total Loss = 2.7504e+01, BC Loss = 4.1091e+01, IC Loss = 2.2850e-01, PDE Loss = 9.9479e-02
# Epoch 15400: Total Loss = 2.7497e+01, BC Loss = 4.1081e+01, IC Loss = 2.2824e-01, PDE Loss = 1.0003e-01
# Epoch 15500: Total Loss = 2.7489e+01, BC Loss = 4.1070e+01, IC Loss = 2.2825e-01, PDE Loss = 1.0053e-01
# Epoch 15600: Total Loss = 2.7481e+01, BC Loss = 4.1057e+01, IC Loss = 2.2853e-01, PDE Loss = 1.0098e-01
# Epoch 15700: Total Loss = 2.7472e+01, BC Loss = 4.1043e+01, IC Loss = 2.2909e-01, PDE Loss = 1.0139e-01
# Epoch 15800: Total Loss = 2.7463e+01, BC Loss = 4.1028e+01, IC Loss = 2.2992e-01, PDE Loss = 1.0176e-01
# Epoch 15900: Total Loss = 2.7452e+01, BC Loss = 4.1012e+01, IC Loss = 2.3105e-01, PDE Loss = 1.0210e-01
# Epoch 16000: Total Loss = 2.7441e+01, BC Loss = 4.0994e+01, IC Loss = 2.3246e-01, PDE Loss = 1.0244e-01
# Epoch 16100: Total Loss = 2.7428e+01, BC Loss = 4.0974e+01, IC Loss = 2.3418e-01, PDE Loss = 1.0278e-01
# Epoch 16200: Total Loss = 2.7414e+01, BC Loss = 4.0952e+01, IC Loss = 2.3621e-01, PDE Loss = 1.0314e-01
# Epoch 16300: Total Loss = 2.7399e+01, BC Loss = 4.0927e+01, IC Loss = 2.3858e-01, PDE Loss = 1.0353e-01
# Epoch 16400: Total Loss = 2.7382e+01, BC Loss = 4.0900e+01, IC Loss = 2.4132e-01, PDE Loss = 1.0398e-01
# Epoch 16500: Total Loss = 2.7363e+01, BC Loss = 4.0871e+01, IC Loss = 2.4445e-01, PDE Loss = 1.0452e-01
# Epoch 16600: Total Loss = 2.7343e+01, BC Loss = 4.0837e+01, IC Loss = 2.4802e-01, PDE Loss = 1.0515e-01
# Epoch 16700: Total Loss = 2.7320e+01, BC Loss = 4.0801e+01, IC Loss = 2.5208e-01, PDE Loss = 1.0593e-01
# Epoch 16800: Total Loss = 2.7294e+01, BC Loss = 4.0760e+01, IC Loss = 2.5671e-01, PDE Loss = 1.0687e-01
# Epoch 16900: Total Loss = 2.7266e+01, BC Loss = 4.0713e+01, IC Loss = 2.6199e-01, PDE Loss = 1.0801e-01
# Epoch 17000: Total Loss = 2.7234e+01, BC Loss = 4.0662e+01, IC Loss = 2.6805e-01, PDE Loss = 1.0941e-01
# Epoch 17100: Total Loss = 2.7197e+01, BC Loss = 4.0603e+01, IC Loss = 2.7503e-01, PDE Loss = 1.1110e-01
# Epoch 17200: Total Loss = 2.7156e+01, BC Loss = 4.0536e+01, IC Loss = 2.8313e-01, PDE Loss = 1.1316e-01
# Epoch 17300: Total Loss = 2.7110e+01, BC Loss = 4.0461e+01, IC Loss = 2.9257e-01, PDE Loss = 1.1564e-01
# Epoch 17400: Total Loss = 2.7057e+01, BC Loss = 4.0374e+01, IC Loss = 3.0369e-01, PDE Loss = 1.1866e-01
# Epoch 17500: Total Loss = 2.6995e+01, BC Loss = 4.0273e+01, IC Loss = 3.1687e-01, PDE Loss = 1.2233e-01
# Epoch 17600: Total Loss = 2.6925e+01, BC Loss = 4.0157e+01, IC Loss = 3.3263e-01, PDE Loss = 1.2685e-01
# Epoch 17700: Total Loss = 2.6843e+01, BC Loss = 4.0022e+01, IC Loss = 3.5166e-01, PDE Loss = 1.3253e-01
# Epoch 17800: Total Loss = 2.6748e+01, BC Loss = 3.9864e+01, IC Loss = 3.7479e-01, PDE Loss = 1.3991e-01
# Epoch 17900: Total Loss = 2.6636e+01, BC Loss = 3.9677e+01, IC Loss = 4.0306e-01, PDE Loss = 1.4997e-01
# Epoch 18000: Total Loss = 2.6505e+01, BC Loss = 3.9457e+01, IC Loss = 4.3764e-01, PDE Loss = 1.6452e-01
# Epoch 18100: Total Loss = 2.6352e+01, BC Loss = 3.9195e+01, IC Loss = 4.7960e-01, PDE Loss = 1.8676e-01
# Epoch 18200: Total Loss = 2.6173e+01, BC Loss = 3.8884e+01, IC Loss = 5.2958e-01, PDE Loss = 2.2193e-01
# Epoch 18300: Total Loss = 2.5966e+01, BC Loss = 3.8516e+01, IC Loss = 5.8733e-01, PDE Loss = 2.7755e-01
# Epoch 18400: Total Loss = 2.5725e+01, BC Loss = 3.8080e+01, IC Loss = 6.5170e-01, PDE Loss = 3.6333e-01
# Epoch 18500: Total Loss = 2.5442e+01, BC Loss = 3.7557e+01, IC Loss = 7.2075e-01, PDE Loss = 4.9109e-01
# Epoch 18600: Total Loss = 2.5105e+01, BC Loss = 3.6924e+01, IC Loss = 7.9031e-01, PDE Loss = 6.7562e-01
# Epoch 18700: Total Loss = 2.4691e+01, BC Loss = 3.6145e+01, IC Loss = 8.4695e-01, PDE Loss = 9.3591e-01
# Epoch 18800: Total Loss = 2.4193e+01, BC Loss = 3.5215e+01, IC Loss = 8.5737e-01, PDE Loss = 1.2897e+00
# Epoch 18900: Total Loss = 2.3661e+01, BC Loss = 3.4241e+01, IC Loss = 7.9280e-01, PDE Loss = 1.7077e+00
# Epoch 19000: Total Loss = 2.3168e+01, BC Loss = 3.3366e+01, IC Loss = 7.0324e-01, PDE Loss = 2.0694e+00
# Epoch 19100: Total Loss = 2.2691e+01, BC Loss = 3.2557e+01, IC Loss = 6.5342e-01, PDE Loss = 2.3052e+00
# Epoch 19200: Total Loss = 2.2176e+01, BC Loss = 3.1723e+01, IC Loss = 6.3375e-01, PDE Loss = 2.4484e+00
# Epoch 19300: Total Loss = 2.1599e+01, BC Loss = 3.0826e+01, IC Loss = 6.2141e-01, PDE Loss = 2.5250e+00
# Epoch 19400: Total Loss = 2.0969e+01, BC Loss = 2.9877e+01, IC Loss = 6.0606e-01, PDE Loss = 2.5470e+00
# Epoch 19500: Total Loss = 2.0317e+01, BC Loss = 2.8914e+01, IC Loss = 5.8257e-01, PDE Loss = 2.5399e+00
# Epoch 19600: Total Loss = 1.9662e+01, BC Loss = 2.7953e+01, IC Loss = 5.5541e-01, PDE Loss = 2.5255e+00
# Epoch 19700: Total Loss = 1.9006e+01, BC Loss = 2.6984e+01, IC Loss = 5.3604e-01, PDE Loss = 2.5153e+00
# Epoch 19800: Total Loss = 1.8330e+01, BC Loss = 2.5982e+01, IC Loss = 5.0698e-01, PDE Loss = 2.5186e+00
# Epoch 19900: Total Loss = 1.7568e+01, BC Loss = 2.4849e+01, IC Loss = 4.8452e-01, PDE Loss = 2.5212e+00
# Epoch 20000: Total Loss = 1.6617e+01, BC Loss = 2.3412e+01, IC Loss = 4.7982e-01, PDE Loss = 2.5450e+00
# Epoch 20100: Total Loss = 1.5334e+01, BC Loss = 2.1429e+01, IC Loss = 4.9553e-01, PDE Loss = 2.6469e+00
# Epoch 20200: Total Loss = 1.3563e+01, BC Loss = 1.8584e+01, IC Loss = 5.2841e-01, PDE Loss = 2.9923e+00
# Epoch 20300: Total Loss = 1.1276e+01, BC Loss = 1.4823e+01, IC Loss = 5.5962e-01, PDE Loss = 3.6209e+00
# Epoch 20400: Total Loss = 8.8779e+00, BC Loss = 1.0804e+01, IC Loss = 5.7144e-01, PDE Loss = 4.4545e+00
# Epoch 20500: Total Loss = 6.9953e+00, BC Loss = 7.5112e+00, IC Loss = 5.7252e-01, PDE Loss = 5.3911e+00
# Epoch 20600: Total Loss = 5.7975e+00, BC Loss = 5.6457e+00, IC Loss = 5.2810e-01, PDE Loss = 5.5731e+00
# Epoch 20700: Total Loss = 5.0792e+00, BC Loss = 4.3528e+00, IC Loss = 5.1639e-01, PDE Loss = 6.0158e+00
# Epoch 20800: Total Loss = 4.6497e+00, BC Loss = 3.6589e+00, IC Loss = 4.9248e-01, PDE Loss = 6.1388e+00
# Epoch 20900: Total Loss = 4.4018e+00, BC Loss = 3.5372e+00, IC Loss = 4.4264e-01, PDE Loss = 5.6885e+00
# Epoch 21000: Total Loss = 4.1733e+00, BC Loss = 2.9704e+00, IC Loss = 4.5112e-01, PDE Loss = 6.1279e+00
# Epoch 21100: Total Loss = 4.0227e+00, BC Loss = 2.8281e+00, IC Loss = 4.3098e-01, PDE Loss = 5.9810e+00
# Epoch 21200: Total Loss = 3.8955e+00, BC Loss = 2.6515e+00, IC Loss = 4.2135e-01, PDE Loss = 5.9621e+00
# Epoch 21300: Total Loss = 3.7865e+00, BC Loss = 2.6396e+00, IC Loss = 4.0095e-01, PDE Loss = 5.6794e+00
# Epoch 21400: Total Loss = 3.6781e+00, BC Loss = 2.4531e+00, IC Loss = 3.9930e-01, PDE Loss = 5.7286e+00
# Epoch 21500: Total Loss = 3.5970e+00, BC Loss = 2.2334e+00, IC Loss = 4.0578e-01, PDE Loss = 5.9185e+00
# Epoch 21600: Total Loss = 3.4907e+00, BC Loss = 2.3051e+00, IC Loss = 3.8144e-01, PDE Loss = 5.4803e+00
# Epoch 21700: Total Loss = 3.4087e+00, BC Loss = 2.2403e+00, IC Loss = 3.7373e-01, PDE Loss = 5.3718e+00
# Epoch 21800: Total Loss = 3.3364e+00, BC Loss = 2.1698e+00, IC Loss = 3.6742e-01, PDE Loss = 5.3022e+00
# Epoch 21900: Total Loss = 3.2719e+00, BC Loss = 2.1303e+00, IC Loss = 3.5922e-01, PDE Loss = 5.1957e+00
# Epoch 22000: Total Loss = 3.2152e+00, BC Loss = 2.1292e+00, IC Loss = 3.4836e-01, PDE Loss = 5.0390e+00
# Epoch 22100: Total Loss = 3.1603e+00, BC Loss = 2.0395e+00, IC Loss = 3.4549e-01, PDE Loss = 5.0566e+00
# Epoch 22200: Total Loss = 3.1106e+00, BC Loss = 1.9715e+00, IC Loss = 3.4133e-01, PDE Loss = 5.0473e+00
# Epoch 22300: Total Loss = 3.0615e+00, BC Loss = 1.9614e+00, IC Loss = 3.3258e-01, PDE Loss = 4.9291e+00
# Epoch 22400: Total Loss = 3.0149e+00, BC Loss = 1.9356e+00, IC Loss = 3.2570e-01, PDE Loss = 4.8476e+00
# Epoch 22500: Total Loss = 2.9693e+00, BC Loss = 1.8957e+00, IC Loss = 3.2039e-01, PDE Loss = 4.7959e+00
# Epoch 22600: Total Loss = 2.9250e+00, BC Loss = 1.8855e+00, IC Loss = 3.1307e-01, PDE Loss = 4.6911e+00
# Epoch 22700: Total Loss = 2.8805e+00, BC Loss = 1.8381e+00, IC Loss = 3.0911e-01, PDE Loss = 4.6563e+00
# Epoch 22800: Total Loss = 2.8371e+00, BC Loss = 1.8144e+00, IC Loss = 3.0366e-01, PDE Loss = 4.5786e+00
# Epoch 22900: Total Loss = 2.8870e+00, BC Loss = 2.1934e+00, IC Loss = 2.7662e-01, PDE Loss = 3.9974e+00
# Epoch 23000: Total Loss = 2.7493e+00, BC Loss = 1.7579e+00, IC Loss = 2.9464e-01, PDE Loss = 4.4373e+00
# Epoch 23100: Total Loss = 2.7046e+00, BC Loss = 1.7448e+00, IC Loss = 2.8938e-01, PDE Loss = 4.3348e+00
# Epoch 23200: Total Loss = 2.6595e+00, BC Loss = 1.7049e+00, IC Loss = 2.8674e-01, PDE Loss = 4.2819e+00
# Epoch 23300: Total Loss = 2.6148e+00, BC Loss = 1.7176e+00, IC Loss = 2.7994e-01, PDE Loss = 4.1291e+00
# Epoch 23400: Total Loss = 2.5666e+00, BC Loss = 1.6544e+00, IC Loss = 2.7960e-01, PDE Loss = 4.1113e+00
# Epoch 23500: Total Loss = 2.5193e+00, BC Loss = 1.6262e+00, IC Loss = 2.7658e-01, PDE Loss = 4.0289e+00
# Epoch 23600: Total Loss = 2.4716e+00, BC Loss = 1.6076e+00, IC Loss = 2.7270e-01, PDE Loss = 3.9270e+00
# Epoch 23700: Total Loss = 2.4246e+00, BC Loss = 1.5864e+00, IC Loss = 2.6920e-01, PDE Loss = 3.8318e+00
# Epoch 23800: Total Loss = 2.3813e+00, BC Loss = 1.5178e+00, IC Loss = 2.6994e-01, PDE Loss = 3.8385e+00
# Epoch 23900: Total Loss = 2.3314e+00, BC Loss = 1.5372e+00, IC Loss = 2.6282e-01, PDE Loss = 3.6570e+00
# Epoch 24000: Total Loss = 2.2893e+00, BC Loss = 1.4775e+00, IC Loss = 2.6282e-01, PDE Loss = 3.6502e+00
# Epoch 24100: Total Loss = 2.2412e+00, BC Loss = 1.4923e+00, IC Loss = 2.5625e-01, PDE Loss = 3.4827e+00
# Epoch 24200: Total Loss = 2.2398e+00, BC Loss = 1.6614e+00, IC Loss = 2.4291e-01, PDE Loss = 3.1537e+00
# Epoch 24300: Total Loss = 2.1545e+00, BC Loss = 1.4505e+00, IC Loss = 2.4984e-01, PDE Loss = 3.3126e+00
# Epoch 24400: Total Loss = 2.1134e+00, BC Loss = 1.4507e+00, IC Loss = 2.4509e-01, PDE Loss = 3.1937e+00
# Epoch 24500: Total Loss = 2.0711e+00, BC Loss = 1.3979e+00, IC Loss = 2.4497e-01, PDE Loss = 3.1725e+00
# Epoch 24600: Total Loss = 2.0304e+00, BC Loss = 1.3860e+00, IC Loss = 2.4170e-01, PDE Loss = 3.0774e+00
# Epoch 24700: Total Loss = 1.9903e+00, BC Loss = 1.3752e+00, IC Loss = 2.3860e-01, PDE Loss = 2.9818e+00
# Epoch 24800: Total Loss = 1.9971e+00, BC Loss = 1.5260e+00, IC Loss = 2.2709e-01, PDE Loss = 2.7121e+00
# Epoch 24900: Total Loss = 1.9124e+00, BC Loss = 1.3314e+00, IC Loss = 2.3455e-01, PDE Loss = 2.8397e+00
# Epoch 25000: Total Loss = 1.8756e+00, BC Loss = 1.3117e+00, IC Loss = 2.3253e-01, PDE Loss = 2.7709e+00
# Epoch 25100: Total Loss = 1.8437e+00, BC Loss = 1.3279e+00, IC Loss = 2.2717e-01, PDE Loss = 2.6481e+00
# Epoch 25200: Total Loss = 1.8279e+00, BC Loss = 1.3790e+00, IC Loss = 2.1975e-01, PDE Loss = 2.5060e+00
# Epoch 25300: Total Loss = 1.7781e+00, BC Loss = 1.2854e+00, IC Loss = 2.2301e-01, PDE Loss = 2.5405e+00
# Epoch 25400: Total Loss = 1.7458e+00, BC Loss = 1.2411e+00, IC Loss = 2.2255e-01, PDE Loss = 2.5325e+00
# Epoch 25500: Total Loss = 1.7172e+00, BC Loss = 1.2239e+00, IC Loss = 2.2001e-01, PDE Loss = 2.4838e+00
# Epoch 25600: Total Loss = 1.6912e+00, BC Loss = 1.2283e+00, IC Loss = 2.1497e-01, PDE Loss = 2.4021e+00
# Epoch 25700: Total Loss = 1.6727e+00, BC Loss = 1.2484e+00, IC Loss = 2.0946e-01, PDE Loss = 2.3118e+00
# Epoch 25800: Total Loss = 1.6434e+00, BC Loss = 1.2082e+00, IC Loss = 2.0944e-01, PDE Loss = 2.3044e+00
# Epoch 25900: Total Loss = 1.6159e+00, BC Loss = 1.1627e+00, IC Loss = 2.0925e-01, PDE Loss = 2.3130e+00
# Epoch 26000: Total Loss = 1.5932e+00, BC Loss = 1.1481e+00, IC Loss = 2.0696e-01, PDE Loss = 2.2765e+00
# Epoch 26100: Total Loss = 1.5720e+00, BC Loss = 1.1506e+00, IC Loss = 2.0207e-01, PDE Loss = 2.2125e+00
# Epoch 26200: Total Loss = 1.5500e+00, BC Loss = 1.1230e+00, IC Loss = 2.0210e-01, PDE Loss = 2.2019e+00
# Epoch 26300: Total Loss = 1.5288e+00, BC Loss = 1.1121e+00, IC Loss = 1.9904e-01, PDE Loss = 2.1632e+00
# Epoch 26400: Total Loss = 1.5074e+00, BC Loss = 1.0965e+00, IC Loss = 1.9780e-01, PDE Loss = 2.1313e+00
# Epoch 26500: Total Loss = 1.4860e+00, BC Loss = 1.0852e+00, IC Loss = 1.9570e-01, PDE Loss = 2.0920e+00
# Epoch 26600: Total Loss = 1.5752e+00, BC Loss = 1.1175e+00, IC Loss = 2.0751e-01, PDE Loss = 2.2833e+00
# Epoch 26700: Total Loss = 1.4411e+00, BC Loss = 1.0546e+00, IC Loss = 1.9193e-01, PDE Loss = 2.0222e+00
# Epoch 26800: Total Loss = 1.4187e+00, BC Loss = 1.0314e+00, IC Loss = 1.9154e-01, PDE Loss = 2.0018e+00
# Epoch 26900: Total Loss = 1.3955e+00, BC Loss = 1.0163e+00, IC Loss = 1.8853e-01, PDE Loss = 1.9654e+00
# Epoch 27000: Total Loss = 1.3683e+00, BC Loss = 1.0081e+00, IC Loss = 1.8490e-01, PDE Loss = 1.9038e+00
# Epoch 27100: Total Loss = 1.3520e+00, BC Loss = 1.0481e+00, IC Loss = 1.7601e-01, PDE Loss = 1.7838e+00
# Epoch 27200: Total Loss = 1.3165e+00, BC Loss = 9.7990e-01, IC Loss = 1.7967e-01, PDE Loss = 1.8101e+00
# Epoch 27300: Total Loss = 1.2930e+00, BC Loss = 9.7452e-01, IC Loss = 1.7654e-01, PDE Loss = 1.7533e+00
# Epoch 27400: Total Loss = 1.2986e+00, BC Loss = 1.0381e+00, IC Loss = 1.7132e-01, PDE Loss = 1.6484e+00
# Epoch 27500: Total Loss = 1.2473e+00, BC Loss = 9.4291e-01, IC Loss = 1.7465e-01, PDE Loss = 1.6813e+00
# Epoch 27600: Total Loss = 1.2274e+00, BC Loss = 9.2723e-01, IC Loss = 1.7334e-01, PDE Loss = 1.6543e+00
# Epoch 27700: Total Loss = 1.2040e+00, BC Loss = 9.2269e-01, IC Loss = 1.7191e-01, PDE Loss = 1.5945e+00
# Epoch 27800: Total Loss = 1.1828e+00, BC Loss = 9.0766e-01, IC Loss = 1.7116e-01, PDE Loss = 1.5619e+00
# Epoch 27900: Total Loss = 1.1629e+00, BC Loss = 8.9403e-01, IC Loss = 1.7027e-01, PDE Loss = 1.5305e+00
# Epoch 28000: Total Loss = 1.1526e+00, BC Loss = 9.2929e-01, IC Loss = 1.6520e-01, PDE Loss = 1.4339e+00
# Epoch 28100: Total Loss = 1.1221e+00, BC Loss = 8.7902e-01, IC Loss = 1.6716e-01, PDE Loss = 1.4411e+00
# Epoch 28200: Total Loss = 1.1030e+00, BC Loss = 8.7145e-01, IC Loss = 1.6612e-01, PDE Loss = 1.4000e+00
# Epoch 28300: Total Loss = 1.0848e+00, BC Loss = 8.7046e-01, IC Loss = 1.6423e-01, PDE Loss = 1.3491e+00
# Epoch 28400: Total Loss = 1.1364e+00, BC Loss = 9.0123e-01, IC Loss = 1.7474e-01, PDE Loss = 1.4321e+00
# Epoch 28500: Total Loss = 1.0471e+00, BC Loss = 8.4193e-01, IC Loss = 1.6707e-01, PDE Loss = 1.2904e+00
# Epoch 28600: Total Loss = 1.0289e+00, BC Loss = 8.3385e-01, IC Loss = 1.6813e-01, PDE Loss = 1.2508e+00
# Epoch 28700: Total Loss = 1.0109e+00, BC Loss = 8.1646e-01, IC Loss = 1.7190e-01, PDE Loss = 1.2279e+00
# Epoch 28800: Total Loss = 1.0537e+00, BC Loss = 9.4457e-01, IC Loss = 1.6543e-01, PDE Loss = 1.1065e+00
# Epoch 28900: Total Loss = 9.7212e-01, BC Loss = 8.0267e-01, IC Loss = 1.7433e-01, PDE Loss = 1.1367e+00
# Epoch 29000: Total Loss = 9.5218e-01, BC Loss = 7.9079e-01, IC Loss = 1.7584e-01, PDE Loss = 1.0991e+00
# Epoch 29100: Total Loss = 9.3235e-01, BC Loss = 7.8104e-01, IC Loss = 1.7581e-01, PDE Loss = 1.0592e+00
# Epoch 29200: Total Loss = 9.1288e-01, BC Loss = 7.6710e-01, IC Loss = 1.7435e-01, PDE Loss = 1.0301e+00
# Epoch 29300: Total Loss = 8.9350e-01, BC Loss = 7.5758e-01, IC Loss = 1.7135e-01, PDE Loss = 9.9400e-01
# Epoch 29400: Total Loss = 8.7638e-01, BC Loss = 7.4447e-01, IC Loss = 1.6753e-01, PDE Loss = 9.7266e-01
# Epoch 29500: Total Loss = 8.6295e-01, BC Loss = 7.4350e-01, IC Loss = 1.6234e-01, PDE Loss = 9.3953e-01
# Epoch 29600: Total Loss = 8.4737e-01, BC Loss = 7.2319e-01, IC Loss = 1.5915e-01, PDE Loss = 9.3657e-01
# Epoch 29700: Total Loss = 8.3449e-01, BC Loss = 7.0889e-01, IC Loss = 1.5653e-01, PDE Loss = 9.2917e-01
# Epoch 29800: Total Loss = 8.9158e-01, BC Loss = 8.4124e-01, IC Loss = 1.4404e-01, PDE Loss = 8.4822e-01
# Epoch 29900: Total Loss = 8.2233e-01, BC Loss = 7.2320e-01, IC Loss = 1.4537e-01, PDE Loss = 8.7522e-01
# Epoch 30000: Total Loss = 8.0248e-01, BC Loss = 6.8557e-01, IC Loss = 1.4485e-01, PDE Loss = 8.9144e-01
# Epoch 30100: Total Loss = 7.9246e-01, BC Loss = 6.8003e-01, IC Loss = 1.4130e-01, PDE Loss = 8.7603e-01
# Epoch 30200: Total Loss = 7.8367e-01, BC Loss = 6.7215e-01, IC Loss = 1.3877e-01, PDE Loss = 8.6795e-01
# Epoch 30300: Total Loss = 7.7544e-01, BC Loss = 6.6324e-01, IC Loss = 1.3723e-01, PDE Loss = 8.6263e-01
# Epoch 30400: Total Loss = 7.6694e-01, BC Loss = 6.5892e-01, IC Loss = 1.3528e-01, PDE Loss = 8.4770e-01
# Epoch 30500: Total Loss = 7.8368e-01, BC Loss = 6.6762e-01, IC Loss = 1.4031e-01, PDE Loss = 8.7550e-01
# Epoch 30600: Total Loss = 7.4850e-01, BC Loss = 6.4730e-01, IC Loss = 1.3567e-01, PDE Loss = 8.1522e-01
# Epoch 30700: Total Loss = 7.3778e-01, BC Loss = 6.4394e-01, IC Loss = 1.3671e-01, PDE Loss = 7.8873e-01
# Epoch 30800: Total Loss = 7.2658e-01, BC Loss = 6.4169e-01, IC Loss = 1.3734e-01, PDE Loss = 7.5903e-01
# Epoch 30900: Total Loss = 7.1344e-01, BC Loss = 6.3518e-01, IC Loss = 1.3852e-01, PDE Loss = 7.3145e-01
# Epoch 31000: Total Loss = 7.0071e-01, BC Loss = 6.2910e-01, IC Loss = 1.3848e-01, PDE Loss = 7.0544e-01
# Epoch 31100: Total Loss = 6.8909e-01, BC Loss = 6.2426e-01, IC Loss = 1.3768e-01, PDE Loss = 6.8105e-01
# Epoch 31200: Total Loss = 6.7766e-01, BC Loss = 6.1506e-01, IC Loss = 1.3732e-01, PDE Loss = 6.6554e-01
# Epoch 31300: Total Loss = 6.6757e-01, BC Loss = 6.0646e-01, IC Loss = 1.3703e-01, PDE Loss = 6.5276e-01
# Epoch 31400: Total Loss = 6.5756e-01, BC Loss = 6.0462e-01, IC Loss = 1.3412e-01, PDE Loss = 6.2932e-01
# Epoch 31500: Total Loss = 6.4834e-01, BC Loss = 5.9873e-01, IC Loss = 1.3318e-01, PDE Loss = 6.1436e-01
# Epoch 31600: Total Loss = 6.3937e-01, BC Loss = 5.9024e-01, IC Loss = 1.3356e-01, PDE Loss = 6.0407e-01
# Epoch 31700: Total Loss = 6.3025e-01, BC Loss = 5.8296e-01, IC Loss = 1.3433e-01, PDE Loss = 5.9051e-01
# Epoch 31800: Total Loss = 6.1992e-01, BC Loss = 5.8056e-01, IC Loss = 1.3353e-01, PDE Loss = 5.6512e-01
# Epoch 31900: Total Loss = 6.0882e-01, BC Loss = 5.7657e-01, IC Loss = 1.3412e-01, PDE Loss = 5.3920e-01
# Epoch 32000: Total Loss = 5.9757e-01, BC Loss = 5.7196e-01, IC Loss = 1.3584e-01, PDE Loss = 5.1294e-01
# Epoch 32100: Total Loss = 5.9404e-01, BC Loss = 5.9228e-01, IC Loss = 1.3366e-01, PDE Loss = 4.6391e-01
# Epoch 32200: Total Loss = 5.9672e-01, BC Loss = 6.1560e-01, IC Loss = 1.3405e-01, PDE Loss = 4.2491e-01
# Epoch 32300: Total Loss = 5.5057e-01, BC Loss = 5.6188e-01, IC Loss = 1.3609e-01, PDE Loss = 3.9186e-01
# Epoch 32400: Total Loss = 5.3070e-01, BC Loss = 5.5247e-01, IC Loss = 1.3324e-01, PDE Loss = 3.5391e-01
# Epoch 32500: Total Loss = 5.1288e-01, BC Loss = 5.4982e-01, IC Loss = 1.2445e-01, PDE Loss = 3.1454e-01
# Epoch 32600: Total Loss = 4.9792e-01, BC Loss = 5.4206e-01, IC Loss = 1.1687e-01, PDE Loss = 2.9278e-01
# Epoch 32700: Total Loss = 4.8621e-01, BC Loss = 5.3628e-01, IC Loss = 1.0915e-01, PDE Loss = 2.7692e-01
# Epoch 32800: Total Loss = 4.7708e-01, BC Loss = 5.3057e-01, IC Loss = 1.0253e-01, PDE Loss = 2.6756e-01
# Epoch 32900: Total Loss = 4.7484e-01, BC Loss = 5.3759e-01, IC Loss = 9.4876e-02, PDE Loss = 2.5448e-01
# Epoch 33000: Total Loss = 4.6025e-01, BC Loss = 5.1812e-01, IC Loss = 9.0579e-02, PDE Loss = 2.5393e-01
# Epoch 33100: Total Loss = 4.5362e-01, BC Loss = 5.1257e-01, IC Loss = 8.5508e-02, PDE Loss = 2.5022e-01
# Epoch 33200: Total Loss = 4.4861e-01, BC Loss = 5.0964e-01, IC Loss = 8.0497e-02, PDE Loss = 2.4606e-01
# Epoch 33300: Total Loss = 4.4356e-01, BC Loss = 5.0767e-01, IC Loss = 7.5351e-02, PDE Loss = 2.4000e-01
# Epoch 33400: Total Loss = 4.3717e-01, BC Loss = 4.9698e-01, IC Loss = 7.2615e-02, PDE Loss = 2.4493e-01
# Epoch 33500: Total Loss = 4.3277e-01, BC Loss = 4.9241e-01, IC Loss = 6.8945e-02, PDE Loss = 2.4454e-01
# Epoch 33600: Total Loss = 4.8351e-01, BC Loss = 5.8122e-01, IC Loss = 6.1778e-02, PDE Loss = 2.2631e-01
# Epoch 33700: Total Loss = 4.2503e-01, BC Loss = 4.8436e-01, IC Loss = 6.2223e-02, PDE Loss = 2.4415e-01
# Epoch 33800: Total Loss = 4.2289e-01, BC Loss = 4.8155e-01, IC Loss = 5.9474e-02, PDE Loss = 2.4610e-01
# Epoch 33900: Total Loss = 4.2516e-01, BC Loss = 4.8993e-01, IC Loss = 5.5537e-02, PDE Loss = 2.4008e-01
# Epoch 34000: Total Loss = 4.1566e-01, BC Loss = 4.7376e-01, IC Loss = 5.3760e-02, PDE Loss = 2.4570e-01
# Epoch 34100: Total Loss = 4.1301e-01, BC Loss = 4.7114e-01, IC Loss = 5.1150e-02, PDE Loss = 2.4559e-01
# Epoch 34200: Total Loss = 4.1055e-01, BC Loss = 4.6865e-01, IC Loss = 4.8683e-02, PDE Loss = 2.4566e-01
# Epoch 34300: Total Loss = 4.0958e-01, BC Loss = 4.6930e-01, IC Loss = 4.6197e-02, PDE Loss = 2.4393e-01
# Epoch 34400: Total Loss = 4.0685e-01, BC Loss = 4.6281e-01, IC Loss = 4.4842e-02, PDE Loss = 2.5008e-01
# Epoch 34500: Total Loss = 4.0398e-01, BC Loss = 4.6008e-01, IC Loss = 4.2654e-02, PDE Loss = 2.4912e-01
# Epoch 34600: Total Loss = 4.0215e-01, BC Loss = 4.5839e-01, IC Loss = 4.0697e-02, PDE Loss = 2.4899e-01
# Epoch 34700: Total Loss = 4.0023e-01, BC Loss = 4.5583e-01, IC Loss = 3.9003e-02, PDE Loss = 2.5002e-01
# Epoch 34800: Total Loss = 3.9856e-01, BC Loss = 4.5292e-01, IC Loss = 3.7519e-02, PDE Loss = 2.5231e-01
# Epoch 34900: Total Loss = 3.9748e-01, BC Loss = 4.5153e-01, IC Loss = 3.5995e-02, PDE Loss = 2.5339e-01
# Epoch 35000: Total Loss = 3.9544e-01, BC Loss = 4.5021e-01, IC Loss = 3.4250e-02, PDE Loss = 2.5165e-01
# Epoch 35100: Total Loss = 3.9420e-01, BC Loss = 4.4777e-01, IC Loss = 3.3014e-02, PDE Loss = 2.5405e-01
# Epoch 35200: Total Loss = 3.9289e-01, BC Loss = 4.4671e-01, IC Loss = 3.1573e-02, PDE Loss = 2.5367e-01
# Epoch 35300: Total Loss = 3.9190e-01, BC Loss = 4.4616e-01, IC Loss = 3.0212e-02, PDE Loss = 2.5318e-01
# Epoch 35400: Total Loss = 3.9049e-01, BC Loss = 4.4284e-01, IC Loss = 2.9277e-02, PDE Loss = 2.5651e-01
# Epoch 35500: Total Loss = 3.8899e-01, BC Loss = 4.4100e-01, IC Loss = 2.8126e-02, PDE Loss = 2.5685e-01
# Epoch 35600: Total Loss = 3.8788e-01, BC Loss = 4.4001e-01, IC Loss = 2.6992e-02, PDE Loss = 2.5663e-01
# Epoch 35700: Total Loss = 3.8684e-01, BC Loss = 4.3802e-01, IC Loss = 2.6096e-02, PDE Loss = 2.5839e-01
# Epoch 35800: Total Loss = 3.8565e-01, BC Loss = 4.3716e-01, IC Loss = 2.5048e-02, PDE Loss = 2.5759e-01
# Epoch 35900: Total Loss = 3.8465e-01, BC Loss = 4.3542e-01, IC Loss = 2.4206e-02, PDE Loss = 2.5891e-01
# Epoch 36000: Total Loss = 3.8378e-01, BC Loss = 4.3495e-01, IC Loss = 2.3259e-02, PDE Loss = 2.5817e-01
# Epoch 36100: Total Loss = 3.8267e-01, BC Loss = 4.3306e-01, IC Loss = 2.2508e-02, PDE Loss = 2.5938e-01
# Epoch 36200: Total Loss = 3.8193e-01, BC Loss = 4.3310e-01, IC Loss = 2.1639e-02, PDE Loss = 2.5796e-01
# Epoch 36300: Total Loss = 3.9079e-01, BC Loss = 4.4427e-01, IC Loss = 2.1174e-02, PDE Loss = 2.6266e-01
# Epoch 36400: Total Loss = 3.8003e-01, BC Loss = 4.3010e-01, IC Loss = 2.0264e-02, PDE Loss = 2.5963e-01
# Epoch 36500: Total Loss = 3.7925e-01, BC Loss = 4.2969e-01, IC Loss = 1.9533e-02, PDE Loss = 2.5884e-01
# Epoch 36600: Total Loss = 4.5913e-01, BC Loss = 5.5750e-01, IC Loss = 1.7845e-02, PDE Loss = 2.4454e-01
# Epoch 36700: Total Loss = 3.7764e-01, BC Loss = 4.2721e-01, IC Loss = 1.8336e-02, PDE Loss = 2.6018e-01
# Epoch 36800: Total Loss = 3.7712e-01, BC Loss = 4.2638e-01, IC Loss = 1.7757e-02, PDE Loss = 2.6086e-01
# Epoch 36900: Total Loss = 3.7615e-01, BC Loss = 4.2552e-01, IC Loss = 1.7149e-02, PDE Loss = 2.6027e-01
# Epoch 37000: Total Loss = 3.7551e-01, BC Loss = 4.2488e-01, IC Loss = 1.6581e-02, PDE Loss = 2.6018e-01
# Epoch 37100: Total Loss = 3.7476e-01, BC Loss = 4.2348e-01, IC Loss = 1.6044e-02, PDE Loss = 2.6127e-01
# Epoch 37200: Total Loss = 3.7407e-01, BC Loss = 4.2291e-01, IC Loss = 1.5537e-02, PDE Loss = 2.6084e-01
# Epoch 37300: Total Loss = 3.7340e-01, BC Loss = 4.2161e-01, IC Loss = 1.5078e-02, PDE Loss = 2.6191e-01
# Epoch 37400: Total Loss = 3.7293e-01, BC Loss = 4.2117e-01, IC Loss = 1.4579e-02, PDE Loss = 2.6188e-01
# Epoch 37500: Total Loss = 3.7273e-01, BC Loss = 4.2263e-01, IC Loss = 1.3958e-02, PDE Loss = 2.5897e-01
# Epoch 37600: Total Loss = 3.7168e-01, BC Loss = 4.1864e-01, IC Loss = 1.3712e-02, PDE Loss = 2.6405e-01
# Epoch 37700: Total Loss = 3.7182e-01, BC Loss = 4.1854e-01, IC Loss = 1.3297e-02, PDE Loss = 2.6508e-01
# Epoch 37800: Total Loss = 3.7023e-01, BC Loss = 4.1801e-01, IC Loss = 1.2736e-02, PDE Loss = 2.6194e-01
# Epoch 37900: Total Loss = 4.1588e-01, BC Loss = 4.9371e-01, IC Loss = 1.1685e-02, PDE Loss = 2.4853e-01
# Epoch 38000: Total Loss = 3.6893e-01, BC Loss = 4.1622e-01, IC Loss = 1.1885e-02, PDE Loss = 2.6247e-01
# Epoch 38100: Total Loss = 3.6866e-01, BC Loss = 4.1578e-01, IC Loss = 1.1516e-02, PDE Loss = 2.6290e-01
# Epoch 38200: Total Loss = 3.6777e-01, BC Loss = 4.1479e-01, IC Loss = 1.1102e-02, PDE Loss = 2.6262e-01
# Epoch 38300: Total Loss = 3.6726e-01, BC Loss = 4.1416e-01, IC Loss = 1.0736e-02, PDE Loss = 2.6273e-01
# Epoch 38400: Total Loss = 3.6661e-01, BC Loss = 4.1331e-01, IC Loss = 1.0356e-02, PDE Loss = 2.6287e-01
# Epoch 38500: Total Loss = 3.6611e-01, BC Loss = 4.1323e-01, IC Loss = 9.9722e-03, PDE Loss = 2.6190e-01
# Epoch 38600: Total Loss = 3.6548e-01, BC Loss = 4.1184e-01, IC Loss = 9.6528e-03, PDE Loss = 2.6311e-01
# Epoch 38700: Total Loss = 3.6497e-01, BC Loss = 4.1063e-01, IC Loss = 9.3546e-03, PDE Loss = 2.6430e-01
# Epoch 38800: Total Loss = 4.1912e-01, BC Loss = 5.0061e-01, IC Loss = 8.4740e-03, PDE Loss = 2.4766e-01
# Epoch 38900: Total Loss = 3.6381e-01, BC Loss = 4.0982e-01, IC Loss = 8.6670e-03, PDE Loss = 2.6313e-01
# Epoch 39000: Total Loss = 3.6363e-01, BC Loss = 4.0946e-01, IC Loss = 8.3603e-03, PDE Loss = 2.6361e-01
# Epoch 39100: Total Loss = 3.6409e-01, BC Loss = 4.1095e-01, IC Loss = 8.0223e-03, PDE Loss = 2.6235e-01
# Epoch 39200: Total Loss = 3.6212e-01, BC Loss = 4.0752e-01, IC Loss = 7.7723e-03, PDE Loss = 2.6357e-01
# Epoch 39300: Total Loss = 3.6339e-01, BC Loss = 4.0842e-01, IC Loss = 7.5485e-03, PDE Loss = 2.6576e-01
# Epoch 39400: Total Loss = 3.7817e-01, BC Loss = 4.3607e-01, IC Loss = 6.9965e-03, PDE Loss = 2.5536e-01
# Epoch 39500: Total Loss = 3.6043e-01, BC Loss = 4.0544e-01, IC Loss = 6.9432e-03, PDE Loss = 2.6347e-01
# Epoch 39600: Total Loss = 3.5987e-01, BC Loss = 4.0444e-01, IC Loss = 6.7034e-03, PDE Loss = 2.6403e-01
# Epoch 39700: Total Loss = 3.6322e-01, BC Loss = 4.1217e-01, IC Loss = 6.3390e-03, PDE Loss = 2.5899e-01
# Epoch 39800: Total Loss = 4.2259e-01, BC Loss = 4.8778e-01, IC Loss = 6.5916e-03, PDE Loss = 2.8561e-01
# Epoch 39900: Total Loss = 3.5813e-01, BC Loss = 4.0211e-01, IC Loss = 5.9708e-03, PDE Loss = 2.6421e-01
# Epoch 40000: Total Loss = 3.5758e-01, BC Loss = 4.0118e-01, IC Loss = 5.7592e-03, PDE Loss = 2.6461e-01
# Epoch 40100: Total Loss = 3.5723e-01, BC Loss = 4.0092e-01, IC Loss = 5.5380e-03, PDE Loss = 2.6433e-01
# Epoch 40200: Total Loss = 3.5738e-01, BC Loss = 4.0497e-01, IC Loss = 5.2090e-03, PDE Loss = 2.5698e-01
# Epoch 40300: Total Loss = 3.5567e-01, BC Loss = 3.9912e-01, IC Loss = 5.1102e-03, PDE Loss = 2.6365e-01
# Epoch 40400: Total Loss = 3.5553e-01, BC Loss = 3.9870e-01, IC Loss = 4.9356e-03, PDE Loss = 2.6427e-01
# Epoch 40500: Total Loss = 3.5461e-01, BC Loss = 3.9805e-01, IC Loss = 4.7202e-03, PDE Loss = 2.6300e-01
# Epoch 40600: Total Loss = 3.5376e-01, BC Loss = 3.9677e-01, IC Loss = 4.5467e-03, PDE Loss = 2.6320e-01
# Epoch 40700: Total Loss = 3.5315e-01, BC Loss = 3.9558e-01, IC Loss = 4.3902e-03, PDE Loss = 2.6390e-01
# Epoch 40800: Total Loss = 3.5331e-01, BC Loss = 3.9776e-01, IC Loss = 4.1734e-03, PDE Loss = 2.6025e-01
# Epoch 40900: Total Loss = 3.5686e-01, BC Loss = 3.9863e-01, IC Loss = 4.1266e-03, PDE Loss = 2.6918e-01
# Epoch 41000: Total Loss = 3.5098e-01, BC Loss = 3.9280e-01, IC Loss = 3.9140e-03, PDE Loss = 2.6341e-01
# Epoch 41100: Total Loss = 3.5027e-01, BC Loss = 3.9152e-01, IC Loss = 3.7865e-03, PDE Loss = 2.6400e-01
# Epoch 41200: Total Loss = 3.5397e-01, BC Loss = 3.9953e-01, IC Loss = 3.5821e-03, PDE Loss = 2.5926e-01
# Epoch 41300: Total Loss = 3.4874e-01, BC Loss = 3.8993e-01, IC Loss = 3.5113e-03, PDE Loss = 2.6283e-01
# Epoch 41400: Total Loss = 3.4793e-01, BC Loss = 3.8888e-01, IC Loss = 3.3940e-03, PDE Loss = 2.6262e-01
# Epoch 41500: Total Loss = 3.4886e-01, BC Loss = 3.8939e-01, IC Loss = 3.3010e-03, PDE Loss = 2.6450e-01
# Epoch 41600: Total Loss = 3.5213e-01, BC Loss = 3.9083e-01, IC Loss = 3.2602e-03, PDE Loss = 2.7146e-01
# Epoch 41700: Total Loss = 3.4539e-01, BC Loss = 3.8488e-01, IC Loss = 3.0827e-03, PDE Loss = 2.6333e-01
# Epoch 41800: Total Loss = 3.4453e-01, BC Loss = 3.8391e-01, IC Loss = 2.9819e-03, PDE Loss = 2.6281e-01
# Epoch 41900: Total Loss = 3.4360e-01, BC Loss = 3.8243e-01, IC Loss = 2.8942e-03, PDE Loss = 2.6305e-01
# Epoch 42000: Total Loss = 3.4269e-01, BC Loss = 3.7991e-01, IC Loss = 2.8249e-03, PDE Loss = 2.6542e-01
# Epoch 42100: Total Loss = 3.4434e-01, BC Loss = 3.8614e-01, IC Loss = 2.6647e-03, PDE Loss = 2.5808e-01
# Epoch 42200: Total Loss = 3.4822e-01, BC Loss = 3.9436e-01, IC Loss = 2.5370e-03, PDE Loss = 2.5340e-01
# Epoch 42300: Total Loss = 3.5119e-01, BC Loss = 3.9389e-01, IC Loss = 2.5246e-03, PDE Loss = 2.6327e-01
# Epoch 42400: Total Loss = 3.3853e-01, BC Loss = 3.7493e-01, IC Loss = 2.4474e-03, PDE Loss = 2.6327e-01
# Epoch 42500: Total Loss = 3.3725e-01, BC Loss = 3.7235e-01, IC Loss = 2.3727e-03, PDE Loss = 2.6468e-01
# Epoch 42600: Total Loss = 3.3653e-01, BC Loss = 3.7090e-01, IC Loss = 2.2963e-03, PDE Loss = 2.6551e-01
# Epoch 42700: Total Loss = 3.4413e-01, BC Loss = 3.8665e-01, IC Loss = 2.1355e-03, PDE Loss = 2.5697e-01
# Epoch 42800: Total Loss = 3.7560e-01, BC Loss = 4.1681e-01, IC Loss = 2.2846e-03, PDE Loss = 2.9091e-01
# Epoch 42900: Total Loss = 3.3235e-01, BC Loss = 3.6452e-01, IC Loss = 2.0390e-03, PDE Loss = 2.6597e-01
# Epoch 43000: Total Loss = 3.3103e-01, BC Loss = 3.6226e-01, IC Loss = 1.9620e-03, PDE Loss = 2.6662e-01
# Epoch 43100: Total Loss = 3.3084e-01, BC Loss = 3.5919e-01, IC Loss = 1.9158e-03, PDE Loss = 2.7222e-01
# Epoch 43200: Total Loss = 3.5139e-01, BC Loss = 3.9834e-01, IC Loss = 1.7306e-03, PDE Loss = 2.5577e-01
# Epoch 43300: Total Loss = 3.3584e-01, BC Loss = 3.7196e-01, IC Loss = 1.6892e-03, PDE Loss = 2.6190e-01
# Epoch 43400: Total Loss = 3.2553e-01, BC Loss = 3.5369e-01, IC Loss = 1.6508e-03, PDE Loss = 2.6756e-01
# Epoch 43500: Total Loss = 3.2357e-01, BC Loss = 3.4904e-01, IC Loss = 1.5945e-03, PDE Loss = 2.7103e-01
# Epoch 43600: Total Loss = 3.2189e-01, BC Loss = 3.4656e-01, IC Loss = 1.5219e-03, PDE Loss = 2.7102e-01
# Epoch 43700: Total Loss = 3.2030e-01, BC Loss = 3.4302e-01, IC Loss = 1.4635e-03, PDE Loss = 2.7340e-01
# Epoch 43800: Total Loss = 3.1851e-01, BC Loss = 3.4120e-01, IC Loss = 1.3853e-03, PDE Loss = 2.7175e-01
# Epoch 43900: Total Loss = 3.1944e-01, BC Loss = 3.4401e-01, IC Loss = 1.3031e-03, PDE Loss = 2.6899e-01
# Epoch 44000: Total Loss = 3.1569e-01, BC Loss = 3.3420e-01, IC Loss = 1.2699e-03, PDE Loss = 2.7740e-01
# Epoch 44100: Total Loss = 3.1249e-01, BC Loss = 3.2952e-01, IC Loss = 1.2102e-03, PDE Loss = 2.7722e-01
# Epoch 44200: Total Loss = 3.1057e-01, BC Loss = 3.2687e-01, IC Loss = 1.1473e-03, PDE Loss = 2.7680e-01
# Epoch 44300: Total Loss = 3.1173e-01, BC Loss = 3.2326e-01, IC Loss = 1.1254e-03, PDE Loss = 2.8754e-01
# Epoch 44400: Total Loss = 3.5575e-01, BC Loss = 4.0986e-01, IC Loss = 9.0774e-04, PDE Loss = 2.4664e-01
# Epoch 44500: Total Loss = 3.1533e-01, BC Loss = 3.3723e-01, IC Loss = 9.4506e-04, PDE Loss = 2.7060e-01
# Epoch 44600: Total Loss = 3.0099e-01, BC Loss = 3.0904e-01, IC Loss = 9.4323e-04, PDE Loss = 2.8396e-01
# Epoch 44700: Total Loss = 2.9847e-01, BC Loss = 3.0366e-01, IC Loss = 9.0384e-04, PDE Loss = 2.8718e-01
# Epoch 44800: Total Loss = 3.1669e-01, BC Loss = 3.4224e-01, IC Loss = 7.6973e-04, PDE Loss = 2.6482e-01
# Epoch 44900: Total Loss = 2.9297e-01, BC Loss = 2.9462e-01, IC Loss = 8.1391e-04, PDE Loss = 2.8886e-01
# Epoch 45000: Total Loss = 2.9249e-01, BC Loss = 2.9232e-01, IC Loss = 7.5952e-04, PDE Loss = 2.9208e-01
# Epoch 45100: Total Loss = 2.8703e-01, BC Loss = 2.8309e-01, IC Loss = 7.4018e-04, PDE Loss = 2.9416e-01
# Epoch 45200: Total Loss = 2.8388e-01, BC Loss = 2.7857e-01, IC Loss = 6.9759e-04, PDE Loss = 2.9381e-01
# Epoch 45300: Total Loss = 2.8114e-01, BC Loss = 2.7496e-01, IC Loss = 6.5388e-04, PDE Loss = 2.9284e-01
# Epoch 45400: Total Loss = 2.8061e-01, BC Loss = 2.6178e-01, IC Loss = 6.7309e-04, PDE Loss = 3.1761e-01
# Epoch 45500: Total Loss = 2.7332e-01, BC Loss = 2.5935e-01, IC Loss = 5.9665e-04, PDE Loss = 3.0067e-01
# Epoch 45600: Total Loss = 2.6963e-01, BC Loss = 2.5347e-01, IC Loss = 5.6278e-04, PDE Loss = 3.0138e-01
# Epoch 45700: Total Loss = 2.7011e-01, BC Loss = 2.4578e-01, IC Loss = 5.6455e-04, PDE Loss = 3.1820e-01
# Epoch 45800: Total Loss = 2.6121e-01, BC Loss = 2.3886e-01, IC Loss = 5.0500e-04, PDE Loss = 3.0543e-01
# Epoch 45900: Total Loss = 2.5732e-01, BC Loss = 2.3439e-01, IC Loss = 4.6930e-04, PDE Loss = 3.0273e-01
# Epoch 46000: Total Loss = 2.5235e-01, BC Loss = 2.2480e-01, IC Loss = 4.5095e-04, PDE Loss = 3.0700e-01
# Epoch 46100: Total Loss = 2.4783e-01, BC Loss = 2.1858e-01, IC Loss = 4.2478e-04, PDE Loss = 3.0590e-01
# Epoch 46200: Total Loss = 2.4298e-01, BC Loss = 2.0737e-01, IC Loss = 4.1638e-04, PDE Loss = 3.1380e-01
# Epoch 46300: Total Loss = 2.3826e-01, BC Loss = 2.0179e-01, IC Loss = 3.8958e-04, PDE Loss = 3.1080e-01
# Epoch 46400: Total Loss = 2.3336e-01, BC Loss = 1.9554e-01, IC Loss = 3.6717e-04, PDE Loss = 3.0862e-01
# Epoch 46500: Total Loss = 2.2949e-01, BC Loss = 1.9598e-01, IC Loss = 3.3358e-04, PDE Loss = 2.9619e-01
# Epoch 46600: Total Loss = 2.2328e-01, BC Loss = 1.8068e-01, IC Loss = 3.3344e-04, PDE Loss = 3.0814e-01
# Epoch 46700: Total Loss = 2.1850e-01, BC Loss = 1.7285e-01, IC Loss = 3.2028e-04, PDE Loss = 3.0950e-01
# Epoch 46800: Total Loss = 2.1276e-01, BC Loss = 1.6562e-01, IC Loss = 3.0411e-04, PDE Loss = 3.0675e-01
# Epoch 46900: Total Loss = 2.0752e-01, BC Loss = 1.6037e-01, IC Loss = 2.8653e-04, PDE Loss = 3.0155e-01
# Epoch 47000: Total Loss = 2.0437e-01, BC Loss = 1.5129e-01, IC Loss = 2.8363e-04, PDE Loss = 3.1024e-01
# Epoch 47100: Total Loss = 1.9617e-01, BC Loss = 1.4341e-01, IC Loss = 2.6600e-04, PDE Loss = 3.0141e-01
# Epoch 47200: Total Loss = 1.9034e-01, BC Loss = 1.3458e-01, IC Loss = 2.5891e-04, PDE Loss = 3.0162e-01
# Epoch 47300: Total Loss = 2.0690e-01, BC Loss = 1.5150e-01, IC Loss = 2.6503e-04, PDE Loss = 3.1744e-01
# Epoch 47400: Total Loss = 1.7840e-01, BC Loss = 1.2201e-01, IC Loss = 2.3491e-04, PDE Loss = 2.9093e-01
# Epoch 47500: Total Loss = 1.7244e-01, BC Loss = 1.1465e-01, IC Loss = 2.2837e-04, PDE Loss = 2.8778e-01
# Epoch 47600: Total Loss = 1.6842e-01, BC Loss = 1.0773e-01, IC Loss = 2.2690e-04, PDE Loss = 2.8957e-01
# Epoch 47700: Total Loss = 1.6158e-01, BC Loss = 9.3786e-02, IC Loss = 2.3210e-04, PDE Loss = 2.9692e-01
# Epoch 47800: Total Loss = 1.5415e-01, BC Loss = 9.6410e-02, IC Loss = 2.0442e-04, PDE Loss = 2.6941e-01
# Epoch 47900: Total Loss = 1.4809e-01, BC Loss = 9.1013e-02, IC Loss = 1.9770e-04, PDE Loss = 2.6205e-01
# Epoch 48000: Total Loss = 1.4183e-01, BC Loss = 8.2694e-02, IC Loss = 1.9638e-04, PDE Loss = 2.5992e-01
# Epoch 48100: Total Loss = 1.3649e-01, BC Loss = 8.2936e-02, IC Loss = 1.8241e-04, PDE Loss = 2.4341e-01
# Epoch 48200: Total Loss = 1.3318e-01, BC Loss = 7.3984e-02, IC Loss = 1.9005e-04, PDE Loss = 2.5137e-01
# Epoch 48300: Total Loss = 1.2773e-01, BC Loss = 8.0616e-02, IC Loss = 1.6742e-04, PDE Loss = 2.2179e-01
# Epoch 48400: Total Loss = 1.1946e-01, BC Loss = 7.3311e-02, IC Loss = 1.6149e-04, PDE Loss = 2.1159e-01
# Epoch 48500: Total Loss = 1.2295e-01, BC Loss = 6.8266e-02, IC Loss = 1.8056e-04, PDE Loss = 2.3212e-01
# Epoch 48600: Total Loss = 1.0598e-01, BC Loss = 5.4806e-02, IC Loss = 1.6587e-04, PDE Loss = 2.0815e-01
# Epoch 48700: Total Loss = 1.0064e-01, BC Loss = 5.1946e-02, IC Loss = 1.6129e-04, PDE Loss = 1.9786e-01
# Epoch 48800: Total Loss = 9.7687e-02, BC Loss = 5.4000e-02, IC Loss = 1.5361e-04, PDE Loss = 1.8491e-01
# Epoch 48900: Total Loss = 9.0737e-02, BC Loss = 4.4791e-02, IC Loss = 1.5619e-04, PDE Loss = 1.8247e-01
# Epoch 49000: Total Loss = 8.6512e-02, BC Loss = 4.0610e-02, IC Loss = 1.5590e-04, PDE Loss = 1.7816e-01
# Epoch 49100: Total Loss = 8.2057e-02, BC Loss = 3.8807e-02, IC Loss = 1.5241e-04, PDE Loss = 1.6840e-01
# Epoch 49200: Total Loss = 7.8157e-02, BC Loss = 3.6032e-02, IC Loss = 1.5070e-04, PDE Loss = 1.6226e-01
# Epoch 49300: Total Loss = 8.0212e-02, BC Loss = 4.6462e-02, IC Loss = 1.4317e-04, PDE Loss = 1.4757e-01
# Epoch 49400: Total Loss = 7.1642e-02, BC Loss = 3.3452e-02, IC Loss = 1.4664e-04, PDE Loss = 1.4788e-01
# Epoch 49500: Total Loss = 6.7834e-02, BC Loss = 2.9181e-02, IC Loss = 1.4690e-04, PDE Loss = 1.4499e-01
# Epoch 49600: Total Loss = 6.4872e-02, BC Loss = 2.6607e-02, IC Loss = 1.4601e-04, PDE Loss = 1.4126e-01
# Epoch 49700: Total Loss = 1.0477e-01, BC Loss = 8.1607e-02, IC Loss = 1.5482e-04, PDE Loss = 1.5094e-01
# Epoch 49800: Total Loss = 5.9415e-02, BC Loss = 2.4592e-02, IC Loss = 1.4130e-04, PDE Loss = 1.2892e-01
# Epoch 49900: Total Loss = 5.7001e-02, BC Loss = 2.2821e-02, IC Loss = 1.3949e-04, PDE Loss = 1.2522e-01
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
